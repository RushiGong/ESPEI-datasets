# %%
from pycalphad import Database, variables as v
from espei.datasets import recursive_glob, load_datasets
from espei.plot import dataplot
from tinydb import where, Query
import matplotlib.pyplot as plt

# %%
dbf = Database('Cr-Fe-phase-new.TDB')
comps = ['CR', 'FE','VA']
#phases = list(dbf.phases.keys())
#print(phases)
conds = {v.N: 1.0, v.P: 101325, v.T: (300, 4000, 20), v.X('FE'): (0, 1, 0.02)}
datasets = load_datasets(recursive_glob('.','*.json'))
#print(datasets.all())
datasets.update({'reference':'MPDS'},Query().reference.search('C9'))

for records in datasets:
    '''
    if records['reference']!='MPDS':
        records['phases']=['EXP']
        print('S=',records)
        for i in range(len(records['values'])):
            print('N=',records['values'][i])
            for j in range(len(records['values'][i])):
                records['values'][i][j][0] = 'EXP
        print('Y=',records)
    '''
    a=records['phases']
    records['phases']=['BCC_A2' if o=='(CR,FE)' else o for o in records['phases']]
    records['phases']=['LIQUID' if o=='L' else o for o in records['phases']]
    records['phases']=['SIGMA' if o=='CR0.5FE0.5_136_TP30' else o for o in records['phases']]
    records['phases']=['FCC_A1' if o=='(FE,NI)' else o for o in records['phases']]
    records['phases']=['FCC_A1' if o=='FE,NI_225_CF4' else o for o in records['phases']]
    records['phases']=['BCC_A2' if o=='(NB6.33FE6.67,NB7NI6)' else o for o in records['phases']]
    datasets.update({'phases':records['phases']},where('phases')==a)
    print(records['phases'])
    for i in range(len(records['values'])):
        for j in range(len(records['values'][i])):
            print('value=',records['values'][i][j])
            records['values'][i][j] = ['BCC_A2' if o=='(CR,FE)' else o for o in records['values'][i][j]]
            records['values'][i][j] = ['LIQUID' if o=='L' else o for o in records['values'][i][j]]
            records['values'][i][j] = ['SIGMA' if o=='CR0.5FE0.5_136_TP30' else o for o in records['values'][i][j]]
            records['values'][i][j] = ['FCC_A1' if o=='(FE,NI)' else o for o in records['values'][i][j]]
            records['values'][i][j] = ['FCC_A1' if o=='FE,NI_225_CF4' else o for o in records['values'][i][j]]
            records['values'][i][j] = ['BCC_A2' if o=='(NB6.33FE6.67,NB7NI6)' else o for o in records['values'][i][j]]
phases_1 = [r['phases'] for r in datasets]
phases_db = []
for i in phases_1:
    for j in i:
        if j not in phases_db:
            phases_db.append(j)
#phases_db.append('EXP')
print(phases_db)
dataplot(comps, phases_db, conds,datasets,tielines=False)
#plt.ylim(1000,1750)
#plt.xlim(0.8,1)
# Out:
# ['BCC_A2', 'LIQUID', 'SIGMA', 'FCC_A1']
# value= ['(CR,FE)', ['FE'], [1.0]]
# value= ['LIQUID', ['FE'], [None]]
# value= ['(CR,FE)', ['FE'], [1.0]]
# value= ['LIQUID', ['FE'], [None]]
# value= ['(CR,FE)', ['FE'], [0.9862439999999999]]
# value= ['LIQUID', ['FE'], [0.9730172453987734]]
# value= ['(CR,FE)', ['FE'], [0.972692]]
# value= ['LIQUID', ['FE'], [0.9479197573964497]]
# value= ['(CR,FE)', ['FE'], [0.9593349999999999]]
# value= ['LIQUID', ['FE'], [0.9245553529411754]]
# value= ['(CR,FE)', ['FE'], [0.9461660000000001]]
# value= ['LIQUID', ['FE'], [0.9029433373493981]]
# value= ['(CR,FE)', ['FE'], [0.93318]]
# value= ['LIQUID', ['FE'], [0.8830186809815953]]
# value= ['(CR,FE)', ['FE'], [0.920368]]
# value= ['LIQUID', ['FE'], [0.864892176470589]]
# value= ['(CR,FE)', ['FE'], [0.9077249999999999]]
# value= ['LIQUID', ['FE'], [0.8484557379310352]]
# value= ['(CR,FE)', ['FE'], [0.895242]]
# value= ['LIQUID', ['FE'], [0.8338597591240864]]
# value= ['(CR,FE)', ['FE'], [0.8829130000000001]]
# value= ['LIQUID', ['FE'], [0.821340671874999]]
# value= ['(CR,FE)', ['FE'], [0.8707309999999999]]
# value= ['LIQUID', ['FE'], [0.8110534745762724]]
# value= ['(CR,FE)', ['FE'], [0.8586879999999999]]
# value= ['LIQUID', ['FE'], [0.8031694661016963]]
# value= ['(CR,FE)', ['FE'], [0.846779]]
# value= ['LIQUID', ['FE'], [0.7976667735849066]]
# value= ['(CR,FE)', ['FE'], [0.834996]]
# value= ['LIQUID', ['FE'], [0.7948533962264156]]
# value= ['(CR,FE)', ['FE'], [0.823331]]
# value= ['LIQUID', ['FE'], [0.7947310754716987]]
# value= ['(CR,FE)', ['FE'], [0.8117789999999999]]
# value= ['LIQUID', ['FE'], [0.797177490566039]]
# value= ['(CR,FE)', ['FE'], [0.800331]]
# value= ['LIQUID', ['FE'], [0.801948]]
# value= ['(CR,FE)', ['FE'], [0.7889820000000001]]
# value= ['LIQUID', ['FE'], [0.773944268456377]]
# value= ['(CR,FE)', ['FE'], [0.734772]]
# value= ['LIQUID', ['FE'], [0.7417338187919473]]
# value= ['(CR,FE)', ['FE'], [0.683672]]
# value= ['LIQUID', ['FE'], [0.7121146980023496]]
# value= ['(CR,FE)', ['FE'], [0.635257]]
# value= ['LIQUID', ['FE'], [0.6786894091743122]]
# value= ['(CR,FE)', ['FE'], [0.589097]]
# value= ['LIQUID', ['FE'], [0.6467040899082568]]
# value= ['(CR,FE)', ['FE'], [0.544767]]
# value= ['LIQUID', ['FE'], [0.6112284760820039]]
# value= ['(CR,FE)', ['FE'], [0.501839]]
# value= ['LIQUID', ['FE'], [0.5732194397905754]]
# value= ['(CR,FE)', ['FE'], [0.459887]]
# value= ['LIQUID', ['FE'], [0.5336987454188481]]
# value= ['(CR,FE)', ['FE'], [0.41848100000000005]]
# value= ['LIQUID', ['FE'], [0.492468245949074]]
# value= ['(CR,FE)', ['FE'], [0.377197]]
# value= ['LIQUID', ['FE'], [0.44887685034013614]]
# value= ['(CR,FE)', ['FE'], [0.335606]]
# value= ['LIQUID', ['FE'], [0.40304622766570597]]
# value= ['(CR,FE)', ['FE'], [0.293281]]
# value= ['LIQUID', ['FE'], [0.3549650687500002]]
# value= ['(CR,FE)', ['FE'], [0.24979500000000002]]
# value= ['LIQUID', ['FE'], [0.30436750545759844]]
# value= ['(CR,FE)', ['FE'], [0.20472100000000001]]
# value= ['LIQUID', ['FE'], [0.25135017326732645]]
# value= ['(CR,FE)', ['FE'], [0.157632]]
# value= ['LIQUID', ['FE'], [0.19518238797213044]]
# value= ['(CR,FE)', ['FE'], [0.1081]]
# value= ['LIQUID', ['FE'], [0.13508274103019532]]
# value= ['(CR,FE)', ['FE'], [0.0556984]]
# value= ['LIQUID', ['FE'], [0.07049466207598386]]
# value= ['(CR,FE)', ['FE'], [0.0]]
# value= ['LIQUID', ['FE'], [None]]
# value= ['(CR,FE)', ['FE'], [0.00782042977736549]]
# value= ['(CR,FE)', ['FE'], [0.00782042977736549]]
# value= ['(CR,FE)', ['FE'], [0.034693100000000004]]
# value= ['(CR,FE)', ['FE'], [0.034693100000000004]]
# value= ['(CR,FE)', ['FE'], [0.0386049]]
# value= ['(CR,FE)', ['FE'], [0.0386049]]
# value= ['(CR,FE)', ['FE'], [0.0426024]]
# value= ['(CR,FE)', ['FE'], [0.0426024]]
# value= ['(CR,FE)', ['FE'], [0.0466841]]
# value= ['(CR,FE)', ['FE'], [0.0466841]]
# value= ['(CR,FE)', ['FE'], [0.0508487]]
# value= ['(CR,FE)', ['FE'], [0.0508487]]
# value= ['(CR,FE)', ['FE'], [0.0550948]]
# value= ['(CR,FE)', ['FE'], [0.0550948]]
# value= ['(CR,FE)', ['FE'], [0.059421]]
# value= ['(CR,FE)', ['FE'], [0.059421]]
# value= ['(CR,FE)', ['FE'], [0.0638258]]
# value= ['(CR,FE)', ['FE'], [0.0638258]]
# value= ['(CR,FE)', ['FE'], [0.068308]]
# value= ['(CR,FE)', ['FE'], [0.068308]]
# value= ['(CR,FE)', ['FE'], [0.072866]]
# value= ['(CR,FE)', ['FE'], [0.072866]]
# value= ['(CR,FE)', ['FE'], [0.0774985]]
# value= ['(CR,FE)', ['FE'], [0.0774985]]
# value= ['(CR,FE)', ['FE'], [0.0822042]]
# value= ['(CR,FE)', ['FE'], [0.0822042]]
# value= ['(CR,FE)', ['FE'], [0.0869815]]
# value= ['(CR,FE)', ['FE'], [0.0869815]]
# value= ['(CR,FE)', ['FE'], [0.0918291]]
# value= ['(CR,FE)', ['FE'], [0.0918291]]
# value= ['(CR,FE)', ['FE'], [0.09674569999999999]]
# value= ['(CR,FE)', ['FE'], [0.09674569999999999]]
# value= ['(CR,FE)', ['FE'], [0.10173]]
# value= ['(CR,FE)', ['FE'], [0.10173]]
# value= ['(CR,FE)', ['FE'], [0.10678000000000001]]
# value= ['(CR,FE)', ['FE'], [0.10678000000000001]]
# value= ['(CR,FE)', ['FE'], [0.11189500000000001]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.509722]]
# value= ['(CR,FE)', ['FE'], [0.133054]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5054572752146781]]
# value= ['(CR,FE)', ['FE'], [0.154978]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5033752950218277]]
# value= ['(CR,FE)', ['FE'], [0.17759799999999998]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5020202395374267]]
# value= ['(CR,FE)', ['FE'], [0.20084700000000003]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5011331418061031]]
# value= ['(CR,FE)', ['FE'], [0.22465800000000002]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5006645382240077]]
# value= ['(CR,FE)', ['FE'], [0.248964]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5005947185742763]]
# value= ['(CR,FE)', ['FE'], [0.273697]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5009145139183697]]
# value= ['(CR,FE)', ['FE'], [0.29879100000000003]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5016562804293772]]
# value= ['(CR,FE)', ['FE'], [0.32417700000000005]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5028785675409315]]
# value= ['(CR,FE)', ['FE'], [0.349789]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5045392823399787]]
# value= ['(CR,FE)', ['FE'], [0.37555900000000003]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5066416757953618]]
# value= ['(CR,FE)', ['FE'], [0.40142000000000005]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5091707846703476]]
# value= ['(CR,FE)', ['FE'], [0.427305]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5121240657913052]]
# value= ['(CR,FE)', ['FE'], [0.453147]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5159270350813304]]
# value= ['(CR,FE)', ['FE'], [0.478877]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5204144327179292]]
# value= ['(CR,FE)', ['FE'], [0.5044299999999999]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5263427977005202]]
# value= ['(CR,FE)', ['FE'], [0.529737]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [None]]
# value= ['(CR,FE)', ['FE'], [0.558208]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5327939815934789]]
# value= ['(CR,FE)', ['FE'], [0.586507]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5392216824749907]]
# value= ['(CR,FE)', ['FE'], [0.614541]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5439260623592176]]
# value= ['(CR,FE)', ['FE'], [0.642217]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5476120519264966]]
# value= ['(CR,FE)', ['FE'], [0.669442]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5503268575969485]]
# value= ['(CR,FE)', ['FE'], [0.696124]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5524889328864173]]
# value= ['(CR,FE)', ['FE'], [0.722169]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5540129630681818]]
# value= ['(CR,FE)', ['FE'], [0.7474850000000001]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.554866718312944]]
# value= ['(CR,FE)', ['FE'], [0.7719790000000001]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.554905899565095]]
# value= ['(CR,FE)', ['FE'], [0.7955580000000001]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5542170931115963]]
# value= ['(CR,FE)', ['FE'], [0.818128]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5528073550389877]]
# value= ['(CR,FE)', ['FE'], [0.8395980000000001]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5506036248252477]]
# value= ['(CR,FE)', ['FE'], [0.8598739999999999]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5474962772038355]]
# value= ['(CR,FE)', ['FE'], [0.878864]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5432979363962289]]
# value= ['(CR,FE)', ['FE'], [0.896473]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5376534619003519]]
# value= ['(CR,FE)', ['FE'], [0.912611]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5296517274901285]]
# value= ['(CR,FE)', ['FE'], [0.927183]]
# value= ['(CR,FE)', ['FE'], [0.927183]]
# value= ['(CR,FE)', ['FE'], [0.9273981823370857]]
# value= ['(CR,FE)', ['FE'], [0.9273981823370857]]
# value= ['(CR,FE)', ['FE'], [0.930534]]
# value= ['(CR,FE)', ['FE'], [0.930534]]
# value= ['(CR,FE)', ['FE'], [0.933729]]
# value= ['(CR,FE)', ['FE'], [0.933729]]
# value= ['(CR,FE)', ['FE'], [0.9367740000000001]]
# value= ['(CR,FE)', ['FE'], [0.9367740000000001]]
# value= ['(CR,FE)', ['FE'], [0.9396760000000001]]
# value= ['(CR,FE)', ['FE'], [0.9396760000000001]]
# value= ['(CR,FE)', ['FE'], [0.9424410000000001]]
# value= ['(CR,FE)', ['FE'], [0.9424410000000001]]
# value= ['(CR,FE)', ['FE'], [0.9450749999999999]]
# value= ['(CR,FE)', ['FE'], [0.9450749999999999]]
# value= ['(CR,FE)', ['FE'], [0.947585]]
# value= ['(CR,FE)', ['FE'], [0.947585]]
# value= ['(CR,FE)', ['FE'], [0.949976]]
# value= ['(CR,FE)', ['FE'], [0.949976]]
# value= ['(CR,FE)', ['FE'], [0.952255]]
# value= ['(CR,FE)', ['FE'], [0.952255]]
# value= ['(CR,FE)', ['FE'], [0.954429]]
# value= ['(CR,FE)', ['FE'], [0.954429]]
# value= ['(CR,FE)', ['FE'], [0.956503]]
# value= ['(CR,FE)', ['FE'], [0.956503]]
# value= ['(CR,FE)', ['FE'], [0.958484]]
# value= ['(CR,FE)', ['FE'], [0.958484]]
# value= ['(CR,FE)', ['FE'], [0.960379]]
# value= ['(CR,FE)', ['FE'], [0.960379]]
# value= ['(CR,FE)', ['FE'], [0.962192]]
# value= ['(CR,FE)', ['FE'], [0.962192]]
# value= ['(CR,FE)', ['FE'], [0.9639319999999999]]
# value= ['(CR,FE)', ['FE'], [0.9639319999999999]]
# value= ['(CR,FE)', ['FE'], [0.965603]]
# value= ['(CR,FE)', ['FE'], [0.965603]]
# value= ['(CR,FE)', ['FE'], [0.967213]]
# value= ['(CR,FE)', ['FE'], [0.967213]]
# value= ['(CR,FE)', ['FE'], [1.0]]
# value= ['(CR,FE)', ['FE'], [None]]
# value= ['(CR,FE)', ['FE'], [1.0]]
# value= ['(CR,FE)', ['FE'], [None]]
# value= ['(CR,FE)', ['FE'], [0.995441]]
# value= ['(CR,FE)', ['FE'], [None]]
# value= ['(CR,FE)', ['FE'], [0.990555]]
# value= ['(CR,FE)', ['FE'], [0.990555]]
# value= ['(CR,FE)', ['FE'], [0.985411]]
# value= ['(CR,FE)', ['FE'], [0.985411]]
# value= ['(CR,FE)', ['FE'], [0.980079]]
# value= ['(CR,FE)', ['FE'], [0.980079]]
# value= ['(CR,FE)', ['FE'], [0.974628]]
# value= ['(CR,FE)', ['FE'], [0.974628]]
# value= ['(CR,FE)', ['FE'], [0.969127]]
# value= ['(CR,FE)', ['FE'], [0.969127]]
# value= ['(CR,FE)', ['FE'], [0.9636450000000001]]
# value= ['(CR,FE)', ['FE'], [0.9636450000000001]]
# value= ['(CR,FE)', ['FE'], [0.9582510000000001]]
# value= ['(CR,FE)', ['FE'], [0.9582510000000001]]
# value= ['(CR,FE)', ['FE'], [0.9530150000000001]]
# value= ['(CR,FE)', ['FE'], [0.9530150000000001]]
# value= ['(CR,FE)', ['FE'], [0.948005]]
# value= ['(CR,FE)', ['FE'], [0.948005]]
# value= ['(CR,FE)', ['FE'], [0.943291]]
# value= ['(CR,FE)', ['FE'], [0.943291]]
# value= ['(CR,FE)', ['FE'], [0.9389409999999999]]
# value= ['(CR,FE)', ['FE'], [0.9389409999999999]]
# value= ['(CR,FE)', ['FE'], [0.935026]]
# value= ['(CR,FE)', ['FE'], [0.935026]]
# value= ['(CR,FE)', ['FE'], [0.931613]]
# value= ['(CR,FE)', ['FE'], [0.931613]]
# value= ['(CR,FE)', ['FE'], [0.9287730000000001]]
# value= ['(CR,FE)', ['FE'], [0.9287730000000001]]
# value= ['(CR,FE)', ['FE'], [0.926574]]
# value= ['FE,NI_225_CF4', ['FE'], [0.9253543957597163]]
# value= ['(CR,FE)', ['FE'], [0.925086]]
# value= ['FE,NI_225_CF4', ['FE'], [0.925086]]
# value= ['(CR,FE)', ['FE'], [0.9105599999999999]]
# value= ['FE,NI_225_CF4', ['FE'], [0.9143494993588099]]
# value= ['(CR,FE)', ['FE'], [0.897332]]
# value= ['FE,NI_225_CF4', ['FE'], [0.904277043322912]]
# value= ['(CR,FE)', ['FE'], [0.8856149999999999]]
# value= ['FE,NI_225_CF4', ['FE'], [0.8958984077226606]]
# value= ['(CR,FE)', ['FE'], [0.875624]]
# value= ['FE,NI_225_CF4', ['FE'], [0.8891534020395155]]
# value= ['(CR,FE)', ['FE'], [0.867573]]
# value= ['FE,NI_225_CF4', ['FE'], [0.8841069019525508]]
# value= ['(CR,FE)', ['FE'], [0.861674]]
# value= ['FE,NI_225_CF4', ['FE'], [0.8808393509385744]]
# value= ['(CR,FE)', ['FE'], [0.858142]]
# value= ['FE,NI_225_CF4', ['FE'], [0.8794382213677561]]
# value= ['(CR,FE)', ['FE'], [0.8571899999999999]]
# value= ['FE,NI_225_CF4', ['FE'], [0.8799969989284621]]
# value= ['(CR,FE)', ['FE'], [0.859032]]
# value= ['FE,NI_225_CF4', ['FE'], [0.8826181096023278]]
# value= ['(CR,FE)', ['FE'], [0.8638819999999999]]
# value= ['FE,NI_225_CF4', ['FE'], [0.8874167453562191]]
# value= ['(CR,FE)', ['FE'], [0.8719540000000001]]
# value= ['FE,NI_225_CF4', ['FE'], [0.8945284839758476]]
# value= ['(CR,FE)', ['FE'], [0.88346]]
# value= ['FE,NI_225_CF4', ['FE'], [0.9041120242763772]]
# value= ['(CR,FE)', ['FE'], [0.898616]]
# value= ['FE,NI_225_CF4', ['FE'], [0.9163686265520535]]
# value= ['(CR,FE)', ['FE'], [0.9176340000000001]]
# value= ['FE,NI_225_CF4', ['FE'], [0.9315664788346614]]
# value= ['(CR,FE)', ['FE'], [0.940728]]
# value= ['FE,NI_225_CF4', ['FE'], [0.9500963560626161]]
# value= ['(CR,FE)', ['FE'], [0.968112]]
# value= ['FE,NI_225_CF4', ['FE'], [0.9725666657963447]]
# ['SIGMA', 'BCC_A2']
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.529546]]
# value= ['(CR,FE)', ['FE'], [0.5249092397550638]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.537064]]
# value= ['(CR,FE)', ['FE'], [0.5684468341708543]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5431779999999999]]
# value= ['(CR,FE)', ['FE'], [0.6068440222222222]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.547951]]
# value= ['(CR,FE)', ['FE'], [0.644234789532294]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.551447]]
# value= ['(CR,FE)', ['FE'], [0.6793310740624016]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5537299999999999]]
# value= ['(CR,FE)', ['FE'], [0.713293248960739]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.554864]]
# value= ['(CR,FE)', ['FE'], [0.7455757516666668]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.554912]]
# value= ['(CR,FE)', ['FE'], [0.7754100549167116]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.553938]]
# value= ['(CR,FE)', ['FE'], [0.802892733199905]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.552007]]
# value= ['(CR,FE)', ['FE'], [0.8279531005490399]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.549181]]
# value= ['(CR,FE)', ['FE'], [0.8503814524542769]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.545525]]
# value= ['(CR,FE)', ['FE'], [0.8700284073619632]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.541102]]
# value= ['(CR,FE)', ['FE'], [0.886816417308331]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.535976]]
# value= ['(CR,FE)', ['FE'], [0.9007450653261815]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.530212]]
# value= ['(CR,FE)', ['FE'], [0.9118425698660514]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.523872]]
# value= ['(CR,FE)', ['FE'], [0.919770340127083]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5170210000000001]]
# value= ['(CR,FE)', ['FE'], [0.11536492630403077]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.509722]]
# value= ['(CR,FE)', ['FE'], [0.11189500000000001]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.508111]]
# value= ['(CR,FE)', ['FE'], [0.11628279895739597]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.506489]]
# value= ['(CR,FE)', ['FE'], [0.12492314525087662]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.504927]]
# value= ['(CR,FE)', ['FE'], [0.13734535432683437]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.503497]]
# value= ['(CR,FE)', ['FE'], [0.15315358447629004]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.502271]]
# value= ['(CR,FE)', ['FE'], [0.17205690341031396]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.501321]]
# value= ['(CR,FE)', ['FE'], [0.19362027714693475]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.500717]]
# value= ['(CR,FE)', ['FE'], [0.21754245806084735]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.500532]]
# value= ['(CR,FE)', ['FE'], [0.24352503313194307]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.500838]]
# value= ['(CR,FE)', ['FE'], [0.27127036288771134]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.501706]]
# value= ['(CR,FE)', ['FE'], [0.3006043542824731]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.503208]]
# value= ['(CR,FE)', ['FE'], [0.33141334974199366]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.505415]]
# value= ['(CR,FE)', ['FE'], [0.3632248901506583]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.5084000000000001]]
# value= ['(CR,FE)', ['FE'], [0.39567266897471415]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.512234]]
# value= ['(CR,FE)', ['FE'], [0.4284953075203102]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.516988]]
# value= ['(CR,FE)', ['FE'], [0.46266311446389063]]
# value= ['CR0.5FE0.5_136_TP30', ['FE'], [0.522735]]
# value= ['(CR,FE)', ['FE'], [0.49642659193913863]]
# ['FCC_A1', 'BCC_A2']
# value= ['FE,NI_225_CF4', ['FE'], [1.0]]
# value= ['(CR,FE)', ['FE'], [None]]
# value= ['FE,NI_225_CF4', ['FE'], [0.995627]]
# value= ['(CR,FE)', ['FE'], [None]]
# value= ['FE,NI_225_CF4', ['FE'], [0.9912529999999999]]
# value= ['(CR,FE)', ['FE'], [0.9943337901771837]]
# value= ['FE,NI_225_CF4', ['FE'], [0.9868779999999999]]
# value= ['(CR,FE)', ['FE'], [0.9912126431457879]]
# value= ['FE,NI_225_CF4', ['FE'], [0.9825]]
# value= ['(CR,FE)', ['FE'], [0.9877697567120046]]
# value= ['FE,NI_225_CF4', ['FE'], [0.97812]]
# value= ['(CR,FE)', ['FE'], [0.9841821037208668]]
# value= ['FE,NI_225_CF4', ['FE'], [0.9737359999999999]]
# value= ['(CR,FE)', ['FE'], [0.9803740513833992]]
# value= ['FE,NI_225_CF4', ['FE'], [0.969349]]
# value= ['(CR,FE)', ['FE'], [0.9761980403302636]]
# value= ['FE,NI_225_CF4', ['FE'], [0.9649559999999999]]
# value= ['(CR,FE)', ['FE'], [0.9718388621464694]]
# value= ['FE,NI_225_CF4', ['FE'], [0.960557]]
# value= ['(CR,FE)', ['FE'], [0.9672828645436197]]
# value= ['FE,NI_225_CF4', ['FE'], [0.956153]]
# value= ['(CR,FE)', ['FE'], [0.9625216799672042]]
# value= ['FE,NI_225_CF4', ['FE'], [0.951741]]
# value= ['(CR,FE)', ['FE'], [0.9575485880149813]]
# value= ['FE,NI_225_CF4', ['FE'], [0.9473220000000001]]
# value= ['(CR,FE)', ['FE'], [0.9523644640522876]]
# value= ['FE,NI_225_CF4', ['FE'], [0.942894]]
# value= ['(CR,FE)', ['FE'], [0.9469919393414209]]
# value= ['FE,NI_225_CF4', ['FE'], [0.938457]]
# value= ['(CR,FE)', ['FE'], [0.9414784999999997]]
# value= ['FE,NI_225_CF4', ['FE'], [0.934011]]
# value= ['FE,NI_225_CF4', ['FE'], [0.934011]]
# value= ['FE,NI_225_CF4', ['FE'], [0.929554]]
# value= ['FE,NI_225_CF4', ['FE'], [0.929554]]
# value= ['FE,NI_225_CF4', ['FE'], [0.925086]]
# value= ['(CR,FE)', ['FE'], [0.925086]]
# value= ['FE,NI_225_CF4', ['FE'], [0.913254]]
# value= ['(CR,FE)', ['FE'], [0.9100920160721286]]
# value= ['FE,NI_225_CF4', ['FE'], [0.903044]]
# value= ['(CR,FE)', ['FE'], [0.8963573255399002]]
# value= ['FE,NI_225_CF4', ['FE'], [0.894537]]
# value= ['(CR,FE)', ['FE'], [0.8843071593046846]]
# value= ['FE,NI_225_CF4', ['FE'], [0.8878149999999999]]
# value= ['(CR,FE)', ['FE'], [0.8742005550105644]]
# value= ['FE,NI_225_CF4', ['FE'], [0.882958]]
# value= ['(CR,FE)', ['FE'], [0.8662743632070864]]
# value= ['FE,NI_225_CF4', ['FE'], [0.88005]]
# value= ['(CR,FE)', ['FE'], [0.8607550537734748]]
# value= ['FE,NI_225_CF4', ['FE'], [0.879172]]
# value= ['(CR,FE)', ['FE'], [0.8578599713411689]]
# value= ['FE,NI_225_CF4', ['FE'], [0.880405]]
# value= ['(CR,FE)', ['FE'], [0.8577931492047461]]
# value= ['FE,NI_225_CF4', ['FE'], [0.883831]]
# value= ['(CR,FE)', ['FE'], [0.8607444546553809]]
# value= ['FE,NI_225_CF4', ['FE'], [0.889532]]
# value= ['(CR,FE)', ['FE'], [0.8668804971751412]]
# value= ['FE,NI_225_CF4', ['FE'], [0.89759]]
# value= ['(CR,FE)', ['FE'], [0.8763336686831085]]
# value= ['FE,NI_225_CF4', ['FE'], [0.908086]]
# value= ['(CR,FE)', ['FE'], [0.8891943205038488]]
# value= ['FE,NI_225_CF4', ['FE'], [0.9211020000000001]]
# value= ['(CR,FE)', ['FE'], [0.9054893777883247]]
# value= ['FE,NI_225_CF4', ['FE'], [0.936719]]
# value= ['(CR,FE)', ['FE'], [0.9251338897058824]]
# value= ['FE,NI_225_CF4', ['FE'], [0.95502]]
# value= ['(CR,FE)', ['FE'], [0.9478753297297297]]
# value= ['FE,NI_225_CF4', ['FE'], [0.976087]]
# value= ['(CR,FE)', ['FE'], [0.9731774958632101]]
# ['LIQUID', 'BCC_A2']
# value= ['LIQUID', ['FE'], [1.0]]
# value= ['(CR,FE)', ['FE'], [None]]
# value= ['LIQUID', ['FE'], [0.043578]]
# value= ['(CR,FE)', ['FE'], [0.03451179834437071]]
# value= ['LIQUID', ['FE'], [0.0867501]]
# value= ['(CR,FE)', ['FE'], [0.06905449092996546]]
# value= ['LIQUID', ['FE'], [0.129668]]
# value= ['(CR,FE)', ['FE'], [0.10381642489093004]]
# value= ['LIQUID', ['FE'], [0.172484]]
# value= ['(CR,FE)', ['FE'], [0.1393065559825774]]
# value= ['LIQUID', ['FE'], [0.21535]]
# value= ['(CR,FE)', ['FE'], [0.17500266906267992]]
# value= ['LIQUID', ['FE'], [0.258419]]
# value= ['(CR,FE)', ['FE'], [0.2110304816498866]]
# value= ['LIQUID', ['FE'], [0.301841]]
# value= ['(CR,FE)', ['FE'], [0.24778943390711286]]
# value= ['LIQUID', ['FE'], [0.345769]]
# value= ['(CR,FE)', ['FE'], [0.2858593036571849]]
# value= ['LIQUID', ['FE'], [0.39035600000000004]]
# value= ['(CR,FE)', ['FE'], [0.32516822457627126]]
# value= ['LIQUID', ['FE'], [0.435753]]
# value= ['(CR,FE)', ['FE'], [0.36617263400293965]]
# value= ['LIQUID', ['FE'], [0.482111]]
# value= ['(CR,FE)', ['FE'], [0.409571974241557]]
# value= ['LIQUID', ['FE'], [0.5295839999999999]]
# value= ['(CR,FE)', ['FE'], [0.45627796351351363]]
# value= ['LIQUID', ['FE'], [0.5783229999999999]]
# value= ['(CR,FE)', ['FE'], [0.5085465000000006]]
# value= ['LIQUID', ['FE'], [0.6284810000000001]]
# value= ['(CR,FE)', ['FE'], [0.568759222222223]]
# value= ['LIQUID', ['FE'], [0.6802079999999999]]
# value= ['(CR,FE)', ['FE'], [0.6381260370370366]]
# value= ['LIQUID', ['FE'], [0.7336579999999999]]
# value= ['(CR,FE)', ['FE'], [0.7244331627906966]]
# value= ['LIQUID', ['FE'], [0.7889820000000001]]
# value= ['(CR,FE)', ['FE'], [1.0]]
# value= ['LIQUID', ['FE'], [0.801948]]
# value= ['(CR,FE)', ['FE'], [0.800331]]
# value= ['LIQUID', ['FE'], [0.815051]]
# value= ['(CR,FE)', ['FE'], [0.7792960634005746]]
# value= ['LIQUID', ['FE'], [0.828249]]
# value= ['(CR,FE)', ['FE'], [0.8895213440000007]]
# value= ['LIQUID', ['FE'], [0.841502]]
# value= ['(CR,FE)', ['FE'], [0.9016043032258072]]
# value= ['LIQUID', ['FE'], [0.854769]]
# value= ['(CR,FE)', ['FE'], [0.9124151451612893]]
# value= ['LIQUID', ['FE'], [0.8680070000000001]]
# value= ['(CR,FE)', ['FE'], [0.922493493087557]]
# value= ['LIQUID', ['FE'], [0.881176]]
# value= ['(CR,FE)', ['FE'], [0.9318220460829493]]
# value= ['LIQUID', ['FE'], [0.894235]]
# value= ['(CR,FE)', ['FE'], [0.9403944444444439]]
# value= ['LIQUID', ['FE'], [0.907142]]
# value= ['(CR,FE)', ['FE'], [0.9486437909407666]]
# value= ['LIQUID', ['FE'], [0.9198569999999999]]
# value= ['(CR,FE)', ['FE'], [0.9563983588850179]]
# value= ['LIQUID', ['FE'], [0.932337]]
# value= ['(CR,FE)', ['FE'], [0.9637048827160499]]
# value= ['LIQUID', ['FE'], [0.944543]]
# value= ['(CR,FE)', ['FE'], [0.9707131851851851]]
# value= ['LIQUID', ['FE'], [0.956432]]
# value= ['(CR,FE)', ['FE'], [0.9772218121546961]]
# value= ['LIQUID', ['FE'], [0.967963]]
# value= ['(CR,FE)', ['FE'], [0.9834737016574586]]
# value= ['LIQUID', ['FE'], [0.979096]]
# value= ['(CR,FE)', ['FE'], [0.9892894825870643]]
# value= ['LIQUID', ['FE'], [0.9897889999999999]]
# value= ['(CR,FE)', ['FE'], [0.9947302885572139]]
# ['BCC_A2', 'FCC_A1']
# value= ['BCC_A2', ['CR'], [0.025517]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.025517]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.029583]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.029583]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.033325]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.033325]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.04166]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.04166]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.054996]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.054996]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.062027]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.062027]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.071711]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.071711]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.084355]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.084355]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.086477]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.086477]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.10619]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.10619]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.107036]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.107036]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.109258]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.109258]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.128065]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.128065]]
# value= ['FCC_A1', ['CR'], [None]]
# ['BCC_A2', 'FCC_A1']
# value= ['BCC_A2', ['CR'], [0.002]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.002]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.022]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.022]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.035]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.035]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.066]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.067]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.086]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.085]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.106]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.106]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.106]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.119]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.119]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.118]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.103]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.12]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.103]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.119]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.104]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.084]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.104]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.084]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.085]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.065]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.085]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.044]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.065]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.039]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.044]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.033]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.02]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.021]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.0001]]
# value= ['FCC_A1', ['CR'], [None]]
# value= ['FCC_A1', ['CR'], [0.0001]]
# value= ['FCC_A1', ['CR'], [None]]
# ['BCC_A2', 'FCC_A1']
# value= ['FCC_A1', ['FE'], [0.866]]
# value= ['BCC_A2', ['FE'], [0.887]]
# ['BCC_A2', 'LIQUID']
# value= ['LIQUID', ['CR'], [0.4888769920668763]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['LIQUID', ['CR'], [0.5254394144576845]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['LIQUID', ['CR'], [0.5990521721202011]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['LIQUID', ['CR'], [0.6785380419757367]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['LIQUID', ['CR'], [0.817981551855826]]
# value= ['BCC_A2', ['CR'], [None]]
# ['BCC_A2', 'LIQUID']
# value= ['BCC_A2', ['CR'], [0.6779710555787244]]
# value= ['LIQUID', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.8213284116414962]]
# value= ['LIQUID', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.9115946375270022]]
# value= ['LIQUID', ['CR'], [None]]
# ['LIQUID', 'BCC_A2']
# value= ['LIQUID', ['CR'], [0.0189]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.0189]]
# value= ['LIQUID', ['CR'], [None]]
# value= ['LIQUID', ['CR'], [0.044]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.044]]
# value= ['LIQUID', ['CR'], [None]]
# value= ['LIQUID', ['CR'], [0.0872]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.0872]]
# value= ['LIQUID', ['CR'], [None]]
# value= ['LIQUID', ['CR'], [0.1435]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.1435]]
# value= ['LIQUID', ['CR'], [None]]
# value= ['LIQUID', ['CR'], [0.1969]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.1969]]
# value= ['LIQUID', ['CR'], [None]]
# value= ['LIQUID', ['CR'], [0.2489]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.2489]]
# value= ['LIQUID', ['CR'], [None]]
# value= ['LIQUID', ['CR'], [0.3305]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.3305]]
# value= ['LIQUID', ['CR'], [None]]
# value= ['LIQUID', ['CR'], [0.3495]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.3495]]
# value= ['LIQUID', ['CR'], [None]]
# value= ['LIQUID', ['CR'], [0.398]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.398]]
# value= ['LIQUID', ['CR'], [None]]
# ['BCC_A2', 'SIGMA']
# value= ['SIGMA', ['CR'], [0.4412326986311844]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['SIGMA', ['CR'], [0.4422560081197383]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['SIGMA', ['CR'], [0.49864091708551517]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['SIGMA', ['CR'], [0.5022238906616058]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['SIGMA', ['CR'], [0.46740077999541185]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['SIGMA', ['CR'], [0.47394940457569507]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['SIGMA', ['CR'], [0.439714418792189]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['SIGMA', ['CR'], [0.4993736400481067]]
# value= ['BCC_A2', ['CR'], [None]]
# ['BCC_A2', 'SIGMA']
# value= ['BCC_A2', ['CR'], [0.44113954409893846]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.4350678151091091]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.4232135532892588]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.3608208721766878]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.5084791479836216]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.5239511425333863]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.5824980708669628]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.471418938177369]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.4994667945803527]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.27652019159245594]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.7302189131507784]]
# value= ['SIGMA', ['CR'], [None]]
# ['BCC_A2', 'BCC_A2']
# value= ['BCC_A2', ['CR'], [0.14283570892723185]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.13263315828957245]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.1044261065266317]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.8792198049512383]]
# value= ['BCC_A2', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.48912228057014256]]
# value= ['BCC_A2', ['CR'], [None]]
# ['BCC_A2', 'SIGMA']
# value= ['BCC_A2', ['CR'], [0.3152984389633746]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.31506507690057844]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.42848020622983374]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.4649624753803025]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.479392418533304]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.4963850660725788]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.505447292844497]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.587616019838887]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.5876829169635552]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.5873208168294498]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.5880734094819675]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.4283860835311726]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.4476839593141023]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.4645478687820679]]
# value= ['SIGMA', ['CR'], [None]]
# value= ['BCC_A2', ['CR'], [0.47932474353509313]]
# value= ['SIGMA', ['CR'], [None]]
# ['BCC_A2', 'LIQUID', 'SIGMA', 'FCC_A1']
# <AxesSubplot:title={'center':'Cr-Fe'}, xlabel='X(FE)', ylabel='Temperature (K)'>
