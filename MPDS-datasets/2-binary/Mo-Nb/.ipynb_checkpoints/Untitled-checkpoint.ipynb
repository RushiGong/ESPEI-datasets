# %%
import os
import json 
from collections import defaultdict
import copy

# %%
with open ('Mo-Nb.exp') as f:
    exp=f.readlines()
    stop=[]
    for i in range(len(exp)):
        exp[i]=exp[i].replace('\n','')
    
        exp[i]=exp[i].split('\t')
        print(exp[i])
        if 'SWAS' in exp[i][0]:
            stop.append(i)
        if '0.55' in exp[i][0]:
            stop.append(i)
        if 'BLOCK_END' in exp[i]:
            stop.append(i)
    print('exp=',stop)
    del exp[0]
    
    for i in range(len(stop)-1):
        cont=copy.deepcopy(exp[stop[i]:stop[i+1]-1])
        print('cont=',cont)
        if '' in cont:
            cont.remove('')
        if len(cont)==0:
            continue;
        print(cont)
        data_re=defaultdict(list)
        for j in range(len(cont)):
            print('a=',cont[j])
            if 'S' in cont[j][1]:
                new=cont[j][1].split(' ')
                cont[j][1]=new[0]

            data_re['c1'].append(float(cont[j][0]))
            data_re['c2'].append(float(cont[j][1]))
            
            
            
        print(data_re)
    
        output={}

        values=data_re
    
#    components=input('The components for '+j+':')
        components='MO,NB' #input components
        components=components.split(',')
        output['components']=components
#    phases=input('The phases for '+j+':')
    
        phase_name=['EXP']
        
        phases=phase_name
        output['phases']=phases
        output['broadcast_conditions']='false'
        output['output']='ZPF'
        output['conditions']={}
        output['conditions']['P']=101325
        output['values']=[]
#    output['reference']=input('The reference'+':')
        print(exp[stop[i+1]-1])
        ref=exp[stop[i+1]-1][-1]

        print('ref',ref)
        output['reference']=ref#input reference 
#    composition=input('The composition reference for '+j+':')
        composition='NB'#input composition 
        region_data={}
        key_points_number=1
        if key_points_number == 1:
            phase_data=phases[0]
            output['conditions']['T']=values['c2']
            for i in values['c1']:
                out=[phase_data,[composition],[i]]
                phases2=copy.deepcopy(phases)
                out1=[phases[0],[composition],['null']]
                output['values'].append([out,out1])
    

        file_name='./ZPF/'+ref[3]+'.json'
        with open(file_name,'w+') as o:
            json.dump(output,o,indent=4)


        out=[]
        n=0
        with open(file_name,'r') as c:
            change=c.readlines()
            work=False
            for i in range(len(change)):
                len_i=change[i].replace('\n','')
                len_i=len_i.replace(' ','')
                if 'values' in change[i]:
                    work=True;
                    len_i='    '+len_i
                if 'reference' in change[i]:
                    work=False
                if work: 
                    out[n-1]=out[n-1]+len_i

                else:
                    out.append(change[i])
                    n=n+1
            print(out)
            name_new='./ZPF/'+'new-'+output['reference']+'.json'
            with open(name_new,'w+') as f:
                for i in out:
                    i=i.replace(']]],',']]],\n')
                    i=i.replace(':[[[',':[\n[[')
                    i=i.replace(']]]],',']]]\n        ],')
                    i=i.replace('[[','             [[')
                    i=i.replace('"null"','null')

                    f.write(i)
# Out:
# ['PROLOG 1']
# ['$ XSCALE       0.100000E-11       1.00000']
# ['$ YSCALE       -9169.99           29.9416']
# ['    ']
# [' XTYPE LINEAR']
# [' YTYPE LINEAR']
# [' XLENGTH        11.5000    ']
# [' YLENGTH        11.5000    ']
# ['$ TITLE   ']
# ['$ XTEXT  MOLE_FRACTION YB']
# ['$ YTEXT  T']
# ['']
# ['DATASET 1']
# ['CHAR 0.25']
# ['COLOR  1']
# ['CHAR 0.25']
# ['SYM 0.22']
# ['BLOCK X=C1; Y=C2; GOC=C3,SWAS']
# ['0.2003442340791738', ' 2620.156562476656 S1']
# ['0.55', ' 2724.1957484499553']
# ['0.3001721170395869', ' 2623.070752451791']
# ['0.7001721170395868', ' 2716.817430928319']
# ['0.9005163511187607', ' 2819.120140437747']
# ['0.55', '0.35', "mna'", 'Kornilov']
# ['0.19277108433734935', ' 2656.3702925074967 S2']
# ['0.3924268502581755', ' 2655.9984953098487']
# ['0.5907056798623064', ' 2738.9579327051338']
# ['0.793115318416523', ' 2817.202674293276']
# ['0.55', '0.3', "mna'", 'Pryakhina']
# ['-0.0013769363166953874', ' 2725.4366376044477 S3']
# ['0.09569707401032701', ' 2753.153243621074']
# ['0.19552495697074013', ' 2762.7636249159614']
# ['0.24509466437177274', ' 2772.653174255925']
# ['0.29259896729776247', ' 2769.3996286296647']
# ['0.3903614457831325', ' 2797.1158077838368']
# ['0.4915662650602409', ' 2809.4534132988997']
# ['0.5900172117039587', ' 2831.713009700449']
# ['0.7944922547332184', ' 2844.978614191042']
# ['0.55', '0.25', "mna'", 'Kocherzhinskii-Solidus']
# ['0.4475043029259895', ' 2785.672052247964 S4']
# ['0.7476764199655764', ' 2845.5036550097643']
# ['0.30154905335628224', ' 2772.37016444876']
# ['0.24922547332185885', ' 2771.410577651616']
# ['0.18450946643717725', ' 2759.7943696842285']
# ['0.9982788296041306', ' 2892.2216163146827']
# ['0.8956970740103268', ' 2874.6767157202767']
# ['0.55', '0.2', "mna'", 'Rudy']
# ['0.1493975903614458', ' 2753.3679554355595 S5']
# ['0.55', '0.15', "mna'", 'Rudy_molten']
# ['0.7476764199655764', ' 2859.3920518211016 S6']
# ['0.4481927710843372', ' 2807.00023477435']
# ['0.30154905335628224', ' 2791.466710064349']
# ['0.24716006884681574', ' 2791.7484392841516']
# ['0.18382099827882958', ' 2771.451129584769']
# ['0.55', '0.1', "mna'", 'Rudy-collapsed']
# ['0.0970740103270224', ' 2757.1205032708335 S7']
# ['0.19414802065404468', ' 2776.4048683662904']
# ['0.2437177280550774', ' 2790.7585452527555']
# ['0.3442340791738381', ' 2790.6962233344357']
# ['0.2919104991394147', ' 2786.264537334457']
# ['0.3917383820998278', ' 2816.211499674517']
# ['0.49087779690189326', ' 2822.846222800858']
# ['0.591394148020654', ' 2842.624467755877']
# ['0.7965576592082616', ' 2849.193454064264']
# ['0.8970740103270222', ' 2875.171876167202']
# ['0.55', '0.05', "mna'", 'Kocherzhinskii-liquidus']
# ['BLOCK_END']
# exp= [17, 19, 23, 28, 38, 46, 48, 54, 65, 66]
# cont= [['0.2003442340791738', ' 2620.156562476656 S1']]
# [['0.2003442340791738', ' 2620.156562476656 S1']]
# a= ['0.2003442340791738', ' 2620.156562476656 S1']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-d0241c94de37> in <module>
#      31
#      32             data_re['c1'].append(float(cont[j][0]))
# ---> 33             data_re['c2'].append(float(cont[j][1]))
#      34
#      35
#
# ValueError: could not convert string to float: ''
