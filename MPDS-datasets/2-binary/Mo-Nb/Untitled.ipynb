# %%
import os
import json 
from collections import defaultdict
import copy

# %%
with open ('Mo-Nb.exp') as f:
    exp=f.readlines()
    stop=[]
    for i in range(len(exp)):
        exp[i]=exp[i].replace('\n','')
    
        exp[i]=exp[i].split('\t')
        print(exp[i])
        if 'SWAS' in exp[i][0]:
            stop.append(i)
        if '0.55' in exp[i][0]:
            stop.append(i)
        if 'BLOCK_END' in exp[i]:
            stop.append(i)
    print('exp=',stop)
    del exp[0]
    
    for i in range(len(stop)-1):
        cont=copy.deepcopy(exp[stop[i]:stop[i+1]-1])
        print('cont=',cont)
        if '' in cont:
            cont.remove('')
        if len(cont)==0:
            continue;
        print(cont)
        data_re=defaultdict(list)
        for j in range(len(cont)):
            print('a=',cont[j])
            if 'S' in cont[j][1]:
                new=cont[j][1].split(' ')
                cont[j][1]=new[1]

            data_re['c1'].append(float(cont[j][0]))
            data_re['c2'].append(float(cont[j][1]))
            
            
            
        print(data_re)
    
        output={}

        values=data_re
    
#    components=input('The components for '+j+':')
        components='MO,NB' #input components
        components=components.split(',')
        output['components']=components
#    phases=input('The phases for '+j+':')
    
        phase_name=['EXP']
        
        phases=phase_name
        output['phases']=phases
        output['broadcast_conditions']='false'
        output['output']='ZPF'
        output['conditions']={}
        output['conditions']['P']=101325
        output['values']=[]
#    output['reference']=input('The reference'+':')
        print(exp[stop[i+1]-1])
        ref=exp[stop[i+1]-1][-1]

        print('ref',ref)
        output['reference']=ref#input reference 
#    composition=input('The composition reference for '+j+':')
        composition='MO'#input composition 
        region_data={}
        key_points_number=1
        if key_points_number == 1:
            phase_data=phases[0]
            output['conditions']['T']=values['c2']
            for i in values['c1']:
                out=[phase_data,[composition],[i]]
                phases2=copy.deepcopy(phases)
                out1=[phases[0],[composition],['null']]
                output['values'].append([out,out1])
    

        file_name='./ZPF/'+ref[3]+'.json'
        with open(file_name,'w+') as o:
            json.dump(output,o,indent=4)


        out=[]
        n=0
        with open(file_name,'r') as c:
            change=c.readlines()
            work=False
            for i in range(len(change)):
                len_i=change[i].replace('\n','')
                len_i=len_i.replace(' ','')
                if 'values' in change[i]:
                    work=True;
                    len_i='    '+len_i
                if 'reference' in change[i]:
                    work=False
                if work: 
                    out[n-1]=out[n-1]+len_i

                else:
                    out.append(change[i])
                    n=n+1
            print(out)
            name_new='./ZPF/'+'new-'+output['reference']+'.json'
            with open(name_new,'w+') as f:
                for i in out:
                    i=i.replace(']]],',']]],\n')
                    i=i.replace(':[[[',':[\n[[')
                    i=i.replace(']]]],',']]]\n        ],')
                    i=i.replace('[[','             [[')
                    i=i.replace('"null"','null')

                    f.write(i)
# Out:
# ['PROLOG 1']
# ['$ XSCALE       0.100000E-11       1.00000']
# ['$ YSCALE       -9169.99           29.9416']
# ['    ']
# [' XTYPE LINEAR']
# [' YTYPE LINEAR']
# [' XLENGTH        11.5000    ']
# [' YLENGTH        11.5000    ']
# ['$ TITLE   ']
# ['$ XTEXT  MOLE_FRACTION YB']
# ['$ YTEXT  T']
# ['']
# ['DATASET 1']
# ['CHAR 0.25']
# ['COLOR  1']
# ['CHAR 0.25']
# ['SYM 0.22']
# ['BLOCK X=C1; Y=C2; GOC=C3,SWAS']
# ['0.2003442340791738', ' 2620.156562476656 S1']
# ['0.55', ' 2724.1957484499553']
# ['0.3001721170395869', ' 2623.070752451791']
# ['0.7001721170395868', ' 2716.817430928319']
# ['0.9005163511187607', ' 2819.120140437747']
# ['0.55', '0.35', "mna'", 'Kornilov']
# ['0.19277108433734935', ' 2656.3702925074967 S2']
# ['0.3924268502581755', ' 2655.9984953098487']
# ['0.5907056798623064', ' 2738.9579327051338']
# ['0.793115318416523', ' 2817.202674293276']
# ['0.55', '0.3', "mna'", 'Pryakhina']
# ['-0.0013769363166953874', ' 2725.4366376044477 S3']
# ['0.09569707401032701', ' 2753.153243621074']
# ['0.19552495697074013', ' 2762.7636249159614']
# ['0.24509466437177274', ' 2772.653174255925']
# ['0.29259896729776247', ' 2769.3996286296647']
# ['0.3903614457831325', ' 2797.1158077838368']
# ['0.4915662650602409', ' 2809.4534132988997']
# ['0.5900172117039587', ' 2831.713009700449']
# ['0.7944922547332184', ' 2844.978614191042']
# ['0.55', '0.25', "mna'", 'Kocherzhinskii-Solidus']
# ['0.4475043029259895', ' 2785.672052247964 S4']
# ['0.7476764199655764', ' 2845.5036550097643']
# ['0.30154905335628224', ' 2772.37016444876']
# ['0.24922547332185885', ' 2771.410577651616']
# ['0.18450946643717725', ' 2759.7943696842285']
# ['0.9982788296041306', ' 2892.2216163146827']
# ['0.8956970740103268', ' 2874.6767157202767']
# ['0.55', '0.2', "mna'", 'Rudy']
# ['0.1493975903614458', ' 2753.3679554355595 S5']
# ['0.55', '0.15', "mna'", 'Rudy_molten']
# ['0.7476764199655764', ' 2859.3920518211016 S6']
# ['0.4481927710843372', ' 2807.00023477435']
# ['0.30154905335628224', ' 2791.466710064349']
# ['0.24716006884681574', ' 2791.7484392841516']
# ['0.18382099827882958', ' 2771.451129584769']
# ['0.55', '0.1', "mna'", 'Rudy-collapsed']
# ['0.0970740103270224', ' 2757.1205032708335 S7']
# ['0.19414802065404468', ' 2776.4048683662904']
# ['0.2437177280550774', ' 2790.7585452527555']
# ['0.3442340791738381', ' 2790.6962233344357']
# ['0.2919104991394147', ' 2786.264537334457']
# ['0.3917383820998278', ' 2816.211499674517']
# ['0.49087779690189326', ' 2822.846222800858']
# ['0.591394148020654', ' 2842.624467755877']
# ['0.7965576592082616', ' 2849.193454064264']
# ['0.8970740103270222', ' 2875.171876167202']
# ['0.55', '0.05', "mna'", 'Kocherzhinskii-liquidus']
# ['BLOCK_END']
# exp= [17, 19, 23, 28, 38, 46, 48, 54, 65, 66]
# cont= [['0.2003442340791738', ' 2620.156562476656 S1']]
# [['0.2003442340791738', ' 2620.156562476656 S1']]
# a= ['0.2003442340791738', ' 2620.156562476656 S1']
# defaultdict(<class 'list'>, {'c1': [0.2003442340791738], 'c2': [2620.156562476656]})
# ['0.55', ' 2724.1957484499553']
# ref  2724.1957484499553
# ['{\n', '    "components": [\n', '        "MO",\n', '        "NB"\n', '    ],\n', '    "phases": [\n', '        "EXP"\n', '    ],\n', '    "broadcast_conditions": "false",\n', '    "output": "ZPF",\n', '    "conditions": {\n', '        "P": 101325,\n', '        "T": [\n', '            2620.156562476656\n', '        ]\n', '    },\n    "values":[[["EXP",["MO"],[0.2003442340791738]],["EXP",["MO"],["null"]]]],', '    "reference": " 2724.1957484499553"\n', '}']
# cont= [['0.3001721170395869', ' 2623.070752451791'], ['0.7001721170395868', ' 2716.817430928319'], ['0.9005163511187607', ' 2819.120140437747']]
# [['0.3001721170395869', ' 2623.070752451791'], ['0.7001721170395868', ' 2716.817430928319'], ['0.9005163511187607', ' 2819.120140437747']]
# a= ['0.3001721170395869', ' 2623.070752451791']
# a= ['0.7001721170395868', ' 2716.817430928319']
# a= ['0.9005163511187607', ' 2819.120140437747']
# defaultdict(<class 'list'>, {'c1': [0.3001721170395869, 0.7001721170395868, 0.9005163511187607], 'c2': [2623.070752451791, 2716.817430928319, 2819.120140437747]})
# ['0.55', '0.35', "mna'", 'Kornilov']
# ref Kornilov
# ['{\n', '    "components": [\n', '        "MO",\n', '        "NB"\n', '    ],\n', '    "phases": [\n', '        "EXP"\n', '    ],\n', '    "broadcast_conditions": "false",\n', '    "output": "ZPF",\n', '    "conditions": {\n', '        "P": 101325,\n', '        "T": [\n', '            2623.070752451791,\n', '            2716.817430928319,\n', '            2819.120140437747\n', '        ]\n', '    },\n    "values":[[["EXP",["MO"],[0.3001721170395869]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.7001721170395868]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.9005163511187607]],["EXP",["MO"],["null"]]]],', '    "reference": "Kornilov"\n', '}']
# cont= [['0.19277108433734935', ' 2656.3702925074967 S2'], ['0.3924268502581755', ' 2655.9984953098487'], ['0.5907056798623064', ' 2738.9579327051338'], ['0.793115318416523', ' 2817.202674293276']]
# [['0.19277108433734935', ' 2656.3702925074967 S2'], ['0.3924268502581755', ' 2655.9984953098487'], ['0.5907056798623064', ' 2738.9579327051338'], ['0.793115318416523', ' 2817.202674293276']]
# a= ['0.19277108433734935', ' 2656.3702925074967 S2']
# a= ['0.3924268502581755', ' 2655.9984953098487']
# a= ['0.5907056798623064', ' 2738.9579327051338']
# a= ['0.793115318416523', ' 2817.202674293276']
# defaultdict(<class 'list'>, {'c1': [0.19277108433734935, 0.3924268502581755, 0.5907056798623064, 0.793115318416523], 'c2': [2656.3702925074967, 2655.9984953098487, 2738.9579327051338, 2817.202674293276]})
# ['0.55', '0.3', "mna'", 'Pryakhina']
# ref Pryakhina
# ['{\n', '    "components": [\n', '        "MO",\n', '        "NB"\n', '    ],\n', '    "phases": [\n', '        "EXP"\n', '    ],\n', '    "broadcast_conditions": "false",\n', '    "output": "ZPF",\n', '    "conditions": {\n', '        "P": 101325,\n', '        "T": [\n', '            2656.3702925074967,\n', '            2655.9984953098487,\n', '            2738.9579327051338,\n', '            2817.202674293276\n', '        ]\n', '    },\n    "values":[[["EXP",["MO"],[0.19277108433734935]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.3924268502581755]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.5907056798623064]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.793115318416523]],["EXP",["MO"],["null"]]]],', '    "reference": "Pryakhina"\n', '}']
# cont= [['-0.0013769363166953874', ' 2725.4366376044477 S3'], ['0.09569707401032701', ' 2753.153243621074'], ['0.19552495697074013', ' 2762.7636249159614'], ['0.24509466437177274', ' 2772.653174255925'], ['0.29259896729776247', ' 2769.3996286296647'], ['0.3903614457831325', ' 2797.1158077838368'], ['0.4915662650602409', ' 2809.4534132988997'], ['0.5900172117039587', ' 2831.713009700449'], ['0.7944922547332184', ' 2844.978614191042']]
# [['-0.0013769363166953874', ' 2725.4366376044477 S3'], ['0.09569707401032701', ' 2753.153243621074'], ['0.19552495697074013', ' 2762.7636249159614'], ['0.24509466437177274', ' 2772.653174255925'], ['0.29259896729776247', ' 2769.3996286296647'], ['0.3903614457831325', ' 2797.1158077838368'], ['0.4915662650602409', ' 2809.4534132988997'], ['0.5900172117039587', ' 2831.713009700449'], ['0.7944922547332184', ' 2844.978614191042']]
# a= ['-0.0013769363166953874', ' 2725.4366376044477 S3']
# a= ['0.09569707401032701', ' 2753.153243621074']
# a= ['0.19552495697074013', ' 2762.7636249159614']
# a= ['0.24509466437177274', ' 2772.653174255925']
# a= ['0.29259896729776247', ' 2769.3996286296647']
# a= ['0.3903614457831325', ' 2797.1158077838368']
# a= ['0.4915662650602409', ' 2809.4534132988997']
# a= ['0.5900172117039587', ' 2831.713009700449']
# a= ['0.7944922547332184', ' 2844.978614191042']
# defaultdict(<class 'list'>, {'c1': [-0.0013769363166953874, 0.09569707401032701, 0.19552495697074013, 0.24509466437177274, 0.29259896729776247, 0.3903614457831325, 0.4915662650602409, 0.5900172117039587, 0.7944922547332184], 'c2': [2725.4366376044477, 2753.153243621074, 2762.7636249159614, 2772.653174255925, 2769.3996286296647, 2797.1158077838368, 2809.4534132988997, 2831.713009700449, 2844.978614191042]})
# ['0.55', '0.25', "mna'", 'Kocherzhinskii-Solidus']
# ref Kocherzhinskii-Solidus
# ['{\n', '    "components": [\n', '        "MO",\n', '        "NB"\n', '    ],\n', '    "phases": [\n', '        "EXP"\n', '    ],\n', '    "broadcast_conditions": "false",\n', '    "output": "ZPF",\n', '    "conditions": {\n', '        "P": 101325,\n', '        "T": [\n', '            2725.4366376044477,\n', '            2753.153243621074,\n', '            2762.7636249159614,\n', '            2772.653174255925,\n', '            2769.3996286296647,\n', '            2797.1158077838368,\n', '            2809.4534132988997,\n', '            2831.713009700449,\n', '            2844.978614191042\n', '        ]\n', '    },\n    "values":[[["EXP",["MO"],[-0.0013769363166953874]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.09569707401032701]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.19552495697074013]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.24509466437177274]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.29259896729776247]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.3903614457831325]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.4915662650602409]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.5900172117039587]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.7944922547332184]],["EXP",["MO"],["null"]]]],', '    "reference": "Kocherzhinskii-Solidus"\n', '}']
# cont= [['0.4475043029259895', ' 2785.672052247964 S4'], ['0.7476764199655764', ' 2845.5036550097643'], ['0.30154905335628224', ' 2772.37016444876'], ['0.24922547332185885', ' 2771.410577651616'], ['0.18450946643717725', ' 2759.7943696842285'], ['0.9982788296041306', ' 2892.2216163146827'], ['0.8956970740103268', ' 2874.6767157202767']]
# [['0.4475043029259895', ' 2785.672052247964 S4'], ['0.7476764199655764', ' 2845.5036550097643'], ['0.30154905335628224', ' 2772.37016444876'], ['0.24922547332185885', ' 2771.410577651616'], ['0.18450946643717725', ' 2759.7943696842285'], ['0.9982788296041306', ' 2892.2216163146827'], ['0.8956970740103268', ' 2874.6767157202767']]
# a= ['0.4475043029259895', ' 2785.672052247964 S4']
# a= ['0.7476764199655764', ' 2845.5036550097643']
# a= ['0.30154905335628224', ' 2772.37016444876']
# a= ['0.24922547332185885', ' 2771.410577651616']
# a= ['0.18450946643717725', ' 2759.7943696842285']
# a= ['0.9982788296041306', ' 2892.2216163146827']
# a= ['0.8956970740103268', ' 2874.6767157202767']
# defaultdict(<class 'list'>, {'c1': [0.4475043029259895, 0.7476764199655764, 0.30154905335628224, 0.24922547332185885, 0.18450946643717725, 0.9982788296041306, 0.8956970740103268], 'c2': [2785.672052247964, 2845.5036550097643, 2772.37016444876, 2771.410577651616, 2759.7943696842285, 2892.2216163146827, 2874.6767157202767]})
# ['0.55', '0.2', "mna'", 'Rudy']
# ref Rudy
# ['{\n', '    "components": [\n', '        "MO",\n', '        "NB"\n', '    ],\n', '    "phases": [\n', '        "EXP"\n', '    ],\n', '    "broadcast_conditions": "false",\n', '    "output": "ZPF",\n', '    "conditions": {\n', '        "P": 101325,\n', '        "T": [\n', '            2785.672052247964,\n', '            2845.5036550097643,\n', '            2772.37016444876,\n', '            2771.410577651616,\n', '            2759.7943696842285,\n', '            2892.2216163146827,\n', '            2874.6767157202767\n', '        ]\n', '    },\n    "values":[[["EXP",["MO"],[0.4475043029259895]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.7476764199655764]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.30154905335628224]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.24922547332185885]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.18450946643717725]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.9982788296041306]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.8956970740103268]],["EXP",["MO"],["null"]]]],', '    "reference": "Rudy"\n', '}']
# cont= [['0.1493975903614458', ' 2753.3679554355595 S5']]
# [['0.1493975903614458', ' 2753.3679554355595 S5']]
# a= ['0.1493975903614458', ' 2753.3679554355595 S5']
# defaultdict(<class 'list'>, {'c1': [0.1493975903614458], 'c2': [2753.3679554355595]})
# ['0.55', '0.15', "mna'", 'Rudy_molten']
# ref Rudy_molten
# ['{\n', '    "components": [\n', '        "MO",\n', '        "NB"\n', '    ],\n', '    "phases": [\n', '        "EXP"\n', '    ],\n', '    "broadcast_conditions": "false",\n', '    "output": "ZPF",\n', '    "conditions": {\n', '        "P": 101325,\n', '        "T": [\n', '            2753.3679554355595\n', '        ]\n', '    },\n    "values":[[["EXP",["MO"],[0.1493975903614458]],["EXP",["MO"],["null"]]]],', '    "reference": "Rudy_molten"\n', '}']
# cont= [['0.7476764199655764', ' 2859.3920518211016 S6'], ['0.4481927710843372', ' 2807.00023477435'], ['0.30154905335628224', ' 2791.466710064349'], ['0.24716006884681574', ' 2791.7484392841516'], ['0.18382099827882958', ' 2771.451129584769']]
# [['0.7476764199655764', ' 2859.3920518211016 S6'], ['0.4481927710843372', ' 2807.00023477435'], ['0.30154905335628224', ' 2791.466710064349'], ['0.24716006884681574', ' 2791.7484392841516'], ['0.18382099827882958', ' 2771.451129584769']]
# a= ['0.7476764199655764', ' 2859.3920518211016 S6']
# a= ['0.4481927710843372', ' 2807.00023477435']
# a= ['0.30154905335628224', ' 2791.466710064349']
# a= ['0.24716006884681574', ' 2791.7484392841516']
# a= ['0.18382099827882958', ' 2771.451129584769']
# defaultdict(<class 'list'>, {'c1': [0.7476764199655764, 0.4481927710843372, 0.30154905335628224, 0.24716006884681574, 0.18382099827882958], 'c2': [2859.3920518211016, 2807.00023477435, 2791.466710064349, 2791.7484392841516, 2771.451129584769]})
# ['0.55', '0.1', "mna'", 'Rudy-collapsed']
# ref Rudy-collapsed
# ['{\n', '    "components": [\n', '        "MO",\n', '        "NB"\n', '    ],\n', '    "phases": [\n', '        "EXP"\n', '    ],\n', '    "broadcast_conditions": "false",\n', '    "output": "ZPF",\n', '    "conditions": {\n', '        "P": 101325,\n', '        "T": [\n', '            2859.3920518211016,\n', '            2807.00023477435,\n', '            2791.466710064349,\n', '            2791.7484392841516,\n', '            2771.451129584769\n', '        ]\n', '    },\n    "values":[[["EXP",["MO"],[0.7476764199655764]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.4481927710843372]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.30154905335628224]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.24716006884681574]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.18382099827882958]],["EXP",["MO"],["null"]]]],', '    "reference": "Rudy-collapsed"\n', '}']
# cont= [['0.0970740103270224', ' 2757.1205032708335 S7'], ['0.19414802065404468', ' 2776.4048683662904'], ['0.2437177280550774', ' 2790.7585452527555'], ['0.3442340791738381', ' 2790.6962233344357'], ['0.2919104991394147', ' 2786.264537334457'], ['0.3917383820998278', ' 2816.211499674517'], ['0.49087779690189326', ' 2822.846222800858'], ['0.591394148020654', ' 2842.624467755877'], ['0.7965576592082616', ' 2849.193454064264'], ['0.8970740103270222', ' 2875.171876167202']]
# [['0.0970740103270224', ' 2757.1205032708335 S7'], ['0.19414802065404468', ' 2776.4048683662904'], ['0.2437177280550774', ' 2790.7585452527555'], ['0.3442340791738381', ' 2790.6962233344357'], ['0.2919104991394147', ' 2786.264537334457'], ['0.3917383820998278', ' 2816.211499674517'], ['0.49087779690189326', ' 2822.846222800858'], ['0.591394148020654', ' 2842.624467755877'], ['0.7965576592082616', ' 2849.193454064264'], ['0.8970740103270222', ' 2875.171876167202']]
# a= ['0.0970740103270224', ' 2757.1205032708335 S7']
# a= ['0.19414802065404468', ' 2776.4048683662904']
# a= ['0.2437177280550774', ' 2790.7585452527555']
# a= ['0.3442340791738381', ' 2790.6962233344357']
# a= ['0.2919104991394147', ' 2786.264537334457']
# a= ['0.3917383820998278', ' 2816.211499674517']
# a= ['0.49087779690189326', ' 2822.846222800858']
# a= ['0.591394148020654', ' 2842.624467755877']
# a= ['0.7965576592082616', ' 2849.193454064264']
# a= ['0.8970740103270222', ' 2875.171876167202']
# defaultdict(<class 'list'>, {'c1': [0.0970740103270224, 0.19414802065404468, 0.2437177280550774, 0.3442340791738381, 0.2919104991394147, 0.3917383820998278, 0.49087779690189326, 0.591394148020654, 0.7965576592082616, 0.8970740103270222], 'c2': [2757.1205032708335, 2776.4048683662904, 2790.7585452527555, 2790.6962233344357, 2786.264537334457, 2816.211499674517, 2822.846222800858, 2842.624467755877, 2849.193454064264, 2875.171876167202]})
# ['0.55', '0.05', "mna'", 'Kocherzhinskii-liquidus']
# ref Kocherzhinskii-liquidus
# ['{\n', '    "components": [\n', '        "MO",\n', '        "NB"\n', '    ],\n', '    "phases": [\n', '        "EXP"\n', '    ],\n', '    "broadcast_conditions": "false",\n', '    "output": "ZPF",\n', '    "conditions": {\n', '        "P": 101325,\n', '        "T": [\n', '            2757.1205032708335,\n', '            2776.4048683662904,\n', '            2790.7585452527555,\n', '            2790.6962233344357,\n', '            2786.264537334457,\n', '            2816.211499674517,\n', '            2822.846222800858,\n', '            2842.624467755877,\n', '            2849.193454064264,\n', '            2875.171876167202\n', '        ]\n', '    },\n    "values":[[["EXP",["MO"],[0.0970740103270224]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.19414802065404468]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.2437177280550774]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.3442340791738381]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.2919104991394147]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.3917383820998278]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.49087779690189326]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.591394148020654]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.7965576592082616]],["EXP",["MO"],["null"]]],[["EXP",["MO"],[0.8970740103270222]],["EXP",["MO"],["null"]]]],', '    "reference": "Kocherzhinskii-liquidus"\n', '}']
# cont= []
