# %%
from pycalphad import Database, variables as v
from espei.datasets import recursive_glob, load_datasets
from espei.plot import dataplot
from tinydb import where, Query
import matplotlib.pyplot as plt

# %%
comps = ['MO', 'NI','VA']
#phases = list(dbf.phases.keys())
#print(phases)
conds = {v.N: 1.0, v.P: 101325, v.T: (300, 4000, 20), v.X('NI'): (0, 1, 0.02)}
datasets = load_datasets(recursive_glob('.','*.json'))

datasets.update({'reference':'MPDS'},Query().reference.search('C10'))
for records in datasets:

    if records['reference']!='MPDS':
        records['phases']=['EXP']
        print('S=',records)
        #for i in range(len(records['conditions']['T'])):
         #   records['conditions']['T'][i]=records['conditions']['T'][i]+273
        
        for i in range(len(records['values'])):
            print('N=',records['values'][i])
            for j in range(len(records['values'][i])):
                records['values'][i][j][0] = 'EXP'
        #print('Y=',records)
   
    a=records['phases']
    records['phases']=['R_PHASE' if o=='MO0.38FE0.62_148_HR159' else o for o in records['phases']]
    records['phases']=['FCC_A1' if o=='FE_PURE' else o for o in records['phases']]
    records['phases']=['MU_PHASE' if o=='NB6.5FE6.5_166_HR39' else o for o in records['phases']]
    records['phases']=['LIQUID' if o=='L' else o for o in records['phases']]
    records['phases']=['SIGMA' if o=='MO0.5FE0.5_136_TP30' else o for o in records['phases']]
    records['phases']=['FCC_A1' if o=='CR0.28NI0.72_225_CF4' or o=='FCC' else o for o in records['phases']]
    records['phases']=['LAVES_PHASE_C14' if o=='NBFE2_194_HP12' else o for o in records['phases']]
    records['phases']=['BCC_A2' if o=='NB_229_CI2'or o=='NB0.002FE0.998_229_CI2' else o for o in records['phases']]
    datasets.update({'phases':records['phases']},where('phases')==a)
    print(records['phases'])
    for i in range(len(records['values'])):
        for j in range(len(records['values'][i])):
            records['values'][i][j] = ['R_PHASE' if o=='MO0.38FE0.62_148_HR159'  else o for o in records['values'][i][j]]
            records['values'][i][j] = ['FCC_A1' if o=='FE_PURE' else o for o in records['values'][i][j]]
            records['values'][i][j] = ['MU_PHASE' if o=='NB6.5FE6.5_166_HR39'  else o for o in records['values'][i][j]]
            records['values'][i][j] = ['LIQUID' if o=='L' else o for o in records['values'][i][j]]
            records['values'][i][j] = ['SIGMA' if o=='MO0.5FE0.5_136_TP30' else o for o in records['values'][i][j]]
            records['values'][i][j] = ['FCC_A1' if o=='CR0.28NI0.72_225_CF4'or o=='FCC' else o for o in records['values'][i][j]]
            records['values'][i][j] = ['LAVES_PHASE_C14' if o=='NBFE2_194_HP12' else o for o in records['values'][i][j]]
            records['values'][i][j] = ['BCC_A2' if o=='NB_229_CI2' or o=='NB0.002FE0.998_229_CI2' else o for o in records['values'][i][j]]
phases_1 = [r['phases'] for r in datasets]
phases_db = []
for i in phases_1:
    for j in i:
        if j not in phases_db:
            phases_db.append(j)
phases_db.append('EXP')
print(phases_db)
dataplot(comps, phases_db, conds,datasets,tielines=False)
plt.ylim(1000,3000)
#plt.xlim(0.0,0.04)
# Out:
# ['LIQUID', 'MO0.98NI0.02_229_CI2', 'MO7NI7_19_OP56', 'MONI4_87_TI10']
# ['MO0.98NI0.02_229_CI2', 'MO7NI7_19_OP56', 'LIQUID']
# ['MO7NI7_19_OP56', 'MO0.98NI0.02_229_CI2', 'LIQUID', 'MONI4_87_TI10', 'MONI3RT']
# ['MONI3RT', 'MO7NI7_19_OP56', 'MONI4_87_TI10', 'MONI3_59_OP8']
# ['MONI3_59_OP8', 'MONI3RT']
# ['MONI4_87_TI10', 'LIQUID', 'MO7NI7_19_OP56', 'MONI3RT', 'MONI3_59_OP8']
# S= {'components': ['MO', 'NI', 'VA'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [
], ['LIQUID', ['NI'], [None]]]
# N= [['BCC_A2', ['NI'], [0.02086466165413528]], ['LIQUID', ['NI'], [None]]]
# N= [['BCC_A2', ['NI'], [0.017481203007518764]], ['LIQUID', ['NI'], [None]]]
# N= [['BCC_A2', ['NI'], [0.011842105263157848]], ['LIQUID', ['NI'], [None]]]
# N= [['BCC_A2', ['NI'], [0.015225563909774364]], ['LIQUID', ['NI'], [None]]]
# N= [['BCC_A2', ['NI'], [0.012969924812030048]], ['LIQUID', ['NI'], [None]]]
# ['EXP']
# S= {'components': ['MO', 'NI', 'VA'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [2171.7617609099543, 2151.531314138215, 2092.8673239282516, 1981.5960677765547, 1933.0460346500847, 1880.436236103597, 1860.2007241223505, 1831.8963333961412, 1783.3488328744247, 1672.0573158846987]}, 'values': [[['LIQUID', ['NI'], [0.37048872180451137]], ['BCC_A2', ['NI'], [None]]], [['LIQUID', ['NI'], [0.37951127819548885]], ['BCC_A2', ['NI'], [None]]], [['LIQUID', ['NI'], [0.4037593984962405]], ['BCC_A2', ['NI'], [None]]], [['LIQUID', ['NI'], [0.4550751879699249]], ['BCC_A2', ['NI'], [None]]], [['LIQUID', ['NI'], [0.4753759398496242]], ['BCC_A2', ['NI'], [None]]], [['LIQUID', ['NI'], [0.5035714285714288]], ['BCC_A2', ['NI'], [None]]], [['LIQUID', ['NI'], [0.5148496240601506]], ['BCC_A2', ['NI'], [None]]], [['LIQUID', ['NI'], [0.5193609022556391]], ['BCC_A2', ['NI'], [None]]], [['LIQUID', ['NI'], [0.5385338345864663]], ['BCC_A2', ['NI'], [None]]], [['LIQUID', ['NI'], [0.5988721804511281]], ['BCC_A2', ['NI'], [None]]]], 'reference': 'Wicker'}
# N= [['LIQUID', ['NI'], [0.37048872180451137]], ['BCC_A2', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.37951127819548885]], ['BCC_A2', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.4037593984962405]], ['BCC_A2', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.4550751879699249]], ['BCC_A2', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.4753759398496242]], ['BCC_A2', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.5035714285714288]], ['BCC_A2', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.5148496240601506]], ['BCC_A2', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.5193609022556391]], ['BCC_A2', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.5385338345864663]], ['BCC_A2', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.5988721804511281]], ['BCC_A2', ['NI'], [None]]]
# ['EXP']
# S= {'components': ['MO', 'NI', 'VA'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1873.4462469836676, 1473.266837262923]}, 'values': [[['BCC_A2', ['NI'], [0.016353383458646564]], ['LIQUID', ['NI'], [None]]], [['BCC_A2', ['NI'], [0.024248120300751852]], ['D_NIMO', ['NI'], [None]]]], 'reference': 'Yaqoob'}
# N= [['BCC_A2', ['NI'], [0.016353383458646564]], ['LIQUID', ['NI'], [None]]]
# N= [['BCC_A2', ['NI'], [0.024248120300751852]], ['D_NIMO', ['NI'], [None]]]
# ['EXP']
# S= {'components': ['MO', 'NI', 'VA'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1609.7188864249465, 1625.478842179097, 1645.0269399755064, 1694.4896063719639, 1714.2654745127911, 1722.2622576946962]}, 'values': [[['LIQUID', ['NI'], [0.6365415467708883]], ['FCC_A1', ['NI'], [None]]], [['LIQUID', ['NI'], [0.6853930294098238]], ['FCC_A1', ['NI'], [None]]], [['LIQUID', ['NI'], [0.7199722470595725]], ['FCC_A1', ['NI'], [None]]], [['LIQUID', ['NI'], [0.7972505199296133]], ['FCC_A1', ['NI'], [None]]], [['LIQUID', ['NI'], [0.8715574410527429]], ['FCC_A1', ['NI'], [None]]], [['LIQUID', ['NI'], [0.9163563636406113]], ['FCC_A1', ['NI'], [None]]]], 'reference': 'Casselton'}
# N= [['LIQUID', ['NI'], [0.6365415467708883]], ['FCC_A1', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.6853930294098238]], ['FCC_A1', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.7199722470595725]], ['FCC_A1', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.7972505199296133]], ['FCC_A1', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.8715574410527429]], ['FCC_A1', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.9163563636406113]], ['FCC_A1', ['NI'], [None]]]
# ['EXP']
# S= {'components': ['MO', 'NI', 'VA'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1609.7188864249465, 1625.478842179097, 1645.0269399755064, 1694.4896063719639, 1714.2654745127911, 1722.2622576946962]}, 'values': [[['LIQUID', ['NI'], [0.6365415467708883]], ['FCC_A1', ['NI'], [None]]], [['LIQUID', ['NI'], [0.6853930294098238]], ['FCC_A1', ['NI'], [None]]], [['LIQUID', ['NI'], [0.7199722470595725]], ['FCC_A1', ['NI'], [None]]], [['LIQUID', ['NI'], [0.7972505199296133]], ['FCC_A1', ['NI'], [None]]], [['LIQUID', ['NI'], [0.8715574410527429]], ['FCC_A1', ['NI'], [None]]], [['LIQUID', ['NI'], [0.9163563636406113]], ['FCC_A1', ['NI'], [None]]]], 'reference': 'Casselton'}
# N= [['LIQUID', ['NI'], [0.6365415467708883]], ['FCC_A1', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.6853930294098238]], ['FCC_A1', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.7199722470595725]], ['FCC_A1', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.7972505199296133]], ['FCC_A1', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.8715574410527429]], ['FCC_A1', ['NI'], [None]]]
# N= [['LIQUID', ['NI'], [0.9163563636406113]], ['FCC_A1', ['NI'], [None]]]
# ['EXP']
# S= {'components': ['MO', 'NI', 'VA'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1024.2774566473988, 973.6673089274245, 800.0, 700.0, 600.0, 500.0, 400.0, 300.0, 200.0, 100.0]}, 'values': [[['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]], [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]], [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]], [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]], [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]], [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]], [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]], [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]], [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]], [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]]], 'reference': 'Kobayashi'}
# N= [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]]
# N= [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]]
# N= [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]]
# N= [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]]
# N= [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]]
# N= [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]]
# N= [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]]
# N= [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]]
# N= [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]]
# N= [['MONI4', ['NI'], [0.79906015037594]], ['DELTA', ['NI'], [0.7584586466165415]]]
# ['EXP']
# S= {'components': ['MO', 'NI', 'VA'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1024.2774566473988, 973.6673089274245, 922.8002569043031, 973.6673089274245, 1024.2774566473988, 1074.1168914579318, 1124.4701348747592]}, 'values': [[['MONI4', ['NI'], [0.8103665073638305]], ['FCC_A1', ['NI'], [None]]], [['MONI4', ['NI'], [0.8103422455480491]], ['FCC_A1', ['NI'], [None]]], [['FCC_A1', ['NI'], [0.8710081769708569]], ['MONI4', ['NI'], [None]]], [['FCC_A1', ['NI'], [0.8680603663534183]], ['MONI4', ['NI'], [None]]], [['FCC_A1', ['NI'], [0.8561958458106187]], ['MONI4', ['NI'], [None]]], [['FCC_A1', ['NI'], [0.8451938512923112]], ['MONI4', ['NI'], [None]]], [['FCC_A1', ['NI'], [0.8264260436429424]], ['MONI4', ['NI'], [None]]]], 'reference': 'Kobayashi'}
# N= [['MONI4', ['NI'], [0.8103665073638305]], ['FCC_A1', ['NI'], [None]]]
# N= [['MONI4', ['NI'], [0.8103422455480491]], ['FCC_A1', ['NI'], [None]]]
# N= [['FCC_A1', ['NI'], [0.8710081769708569]], ['MONI4', ['NI'], [None]]]
# N= [['FCC_A1', ['NI'], [0.8680603663534183]], ['MONI4', ['NI'], [None]]]
# N= [['FCC_A1', ['NI'], [0.8561958458106187]], ['MONI4', ['NI'], [None]]]
# N= [['FCC_A1', ['NI'], [0.8451938512923112]], ['MONI4', ['NI'], [None]]]
# N= [['FCC_A1', ['NI'], [0.8264260436429424]], ['MONI4', ['NI'], [None]]]
# ['EXP']
# S= {'components': ['MO', 'NI', 'VA'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1024.2774566473988, 973.6673089274245, 800.0, 700.0, 600.0, 500.0, 400.0, 300.0, 200.0, 100.0]}, 'values': [[['MONI4', ['NI'], [0.8103665073638305]], ['FCC_A1', ['NI'], [None]]], [['MONI4', ['NI'], [0.8103422455480491]], ['FCC_A1', ['NI'], [None]]], [['MONI4', ['NI'], [0.8103665073638305]], ['FCC_A1', ['NI'], [None]]], [['MONI4', ['NI'], [0.8103422455480491]], ['FCC_A1', ['NI'], [None]]], [['MONI4', ['NI'], [0.8103665073638305]], ['FCC_A1', ['NI'], [None]]], [['MONI4', ['NI'], [0.8103422455480491]], ['FCC_A1', ['NI'], [None]]], [['MONI4', ['NI'], [0.8103665073638305]], ['FCC_A1', ['NI'], [None]]], [['MONI4', ['NI'], [0.8103422455480491]], ['FCC_A1', ['NI'], [None]]], [['MONI4', ['NI'], [0.8103665073638305]], ['FCC_A1', ['NI'], [None]]], [['MONI4', ['NI'], [0.8103422455480491]], ['FCC_A1', ['NI'], [None]]]], 'reference': 'Kobayashi'}
# N= [['MONI4', ['NI'], [0.8103665073638305]], ['FCC_A1', ['NI'], [None]]]
# N= [['MONI4', ['NI'], [0.8103422455480491]], ['FCC_A1', ['NI'], [None]]]
# N= [['MONI4', ['NI'], [0.8103665073638305]], ['FCC_A1', ['NI'], [None]]]
# N= [['MONI4', ['NI'], [0.8103422455480491]], ['FCC_A1', ['NI'], [None]]]
# N= [['MONI4', ['NI'], [0.8103665073638305]], ['FCC_A1', ['NI'], [None]]]
# N= [['MONI4', ['NI'], [0.8103422455480491]], ['FCC_A1', ['NI'], [None]]]
# N= [['MONI4', ['NI'], [0.8103665073638305]], ['FCC_A1', ['NI'], [None]]]
# N= [['MONI4', ['NI'], [0.8103422455480491]], ['FCC_A1', ['NI'], [None]]]
# N= [['MONI4', ['NI'], [0.8103665073638305]], ['FCC_A1', ['NI'], [None]]]
# N= [['MONI4', ['NI'], [0.8103422455480491]], ['FCC_A1', ['NI'], [None]]]
# ['EXP']
# S= {'comment': 'DFT done by shunli', 'reference': 'Unpublished shunli', 'weight': 1, 'phases': ['EXP'], 'components': ['NI', 'MO'], 'conditions': {'P': 101325.0, 'T': 298.15}, 'output': 'HM_FORM', 'solver': {'mode': 'manual', 'sublattice_site_ratios': [1.0, 1.0, 2.0], 'sublattice_configurations': [['MO', 'MO', 'NI'], ['MO', 'NI', 'NI'], ['MO', 'MO', 'MO'], ['NI', 'MO', 'NI'], ['NI', 'MO', 'MO'], ['NI', 'NI', 'MO'], ['MO', 'NI', 'MO']]}, 'values': [[[-1686.5497941600042, -9182.916284849955, 34705.489757400006, -9181.951439429977, 16147.170526409958, -1684.6201033200487, 16142.34629931007]]]}
# N= [[-1686.5497941600042, -9182.916284849955, 34705.489757400006, -9181.951439429977, 16147.170526409958, -1684.6201033200487, 16142.34629931007]]
# ['EXP']
# S= {'comment': 'DFT done by shunli', 'reference': 'Unpublished shunli', 'weight': 1, 'phases': ['EXP'], 'components': ['NI', 'MO'], 'conditions': {'P': 101325.0, 'T': 298.15}, 'output': 'HM_FORM', 'solver': {'mode': 'manual', 'sublattice_site_ratios': [1.0, 1.0, 2.0], 'sublattice_configurations': [['MO', 'MO', 'NI'], ['MO', 'NI', 'NI'], ['MO', 'MO', 'MO'], ['NI', 'MO', 'NI'], ['NI', 'MO', 'MO'], ['NI', 'NI', 'MO'], ['MO', 'NI', 'MO']]}, 'values': [[[-1686.5497941600042, -9182.916284849955, 34705.489757400006, -9181.951439429977, 16147.170526409958, -1684.6201033200487, 16142.34629931007]]]}
# N= [[-1686.5497941600042, -9182.916284849955, 34705.489757400006, -9181.951439429977, 16147.170526409958, -1684.6201033200487, 16142.34629931007]]
# ['EXP']
# S= {'comment': 'DFT done by shunli', 'reference': 'Unpublished shunli', 'weight': 1, 'phases': ['EXP'], 'components': ['MO'], 'conditions': {'P': 101325.0, 'T': 298.15}, 'output': 'HM_FORM', 'solver': {'mode': 'manual', 'sublattice_site_ratios': [1.0, 1.0, 2.0], 'sublattice_configurations': [['MO', 'MO', 'MO']]}, 'values': [[[34705.489757400006]]]}
# N= [[34705.489757400006]]
# ['EXP']
# S= {'comment': 'DFT done by shunli', 'reference': 'Unpublished shunli', 'weight': 1, 'phases': ['EXP'], 'components': ['MO', 'NI'], 'conditions': {'P': 101325.0, 'T': 298.15}, 'output': 'HM_FORM', 'solver': {'mode': 'manual', 'sublattice_site_ratios': [1.0, 1.0, 2.0], 'sublattice_configurations': [['MO', 'MO', 'NI']]}, 'values': [[[-1686.5497941600042]]]}
# N= [[-1686.5497941600042]]
# ['EXP']
# S= {'comment': 'DFT done by shunli', 'reference': 'Unpublished shunli', 'weight': 1, 'phases': ['EXP'], 'components': ['MO', 'NI'], 'conditions': {'P': 101325.0, 'T': 298.15}, 'output': 'HM_FORM', 'solver': {'mode': 'manual', 'sublattice_site_ratios': [1.0, 1.0, 2.0], 'sublattice_configurations': [['MO', 'NI', 'MO']]}, 'values': [[[16142.34629931007]]]}
# N= [[16142.34629931007]]
# ['EXP']
# S= {'comment': 'DFT done by shunli', 'reference': 'Unpublished shunli', 'weight': 1, 'phases': ['EXP'], 'components': ['MO', 'NI'], 'conditions': {'P': 101325.0, 'T': 298.15}, 'output': 'HM_FORM', 'solver': {'mode': 'manual', 'sublattice_site_ratios': [1.0, 1.0, 2.0], 'sublattice_configurations': [['MO', 'NI', 'NI']]}, 'values': [[[-9182.916284849955]]]}
# N= [[-9182.916284849955]]
# ['EXP']
# S= {'comment': 'DFT done by shunli', 'reference': 'Unpublished shunli', 'weight': 1, 'phases': ['EXP'], 'components': ['MO', 'NI'], 'conditions': {'P': 101325.0, 'T': 298.15}, 'output': 'HM_FORM', 'solver': {'mode': 'manual', 'sublattice_site_ratios': [1.0, 1.0, 2.0], 'sublattice_configurations': [['NI', 'MO', 'MO']]}, 'values': [[[16147.170526409958]]]}
# N= [[16147.170526409958]]
# ['EXP']
# S= {'comment': 'DFT done by shunli', 'reference': 'Unpublished shunli', 'weight': 1, 'phases': ['EXP'], 'components': ['MO', 'NI'], 'conditions': {'P': 101325.0, 'T': 298.15}, 'output': 'HM_FORM', 'solver': {'mode': 'manual', 'sublattice_site_ratios': [1.0, 1.0, 2.0], 'sublattice_configurations': [['NI', 'MO', 'NI']]}, 'values': [[[-9181.951439429977]]]}
# N= [[-9181.951439429977]]
# ['EXP']
# S= {'comment': 'DFT done by shunli', 'reference': 'Unpublished shunli', 'weight': 1, 'phases': ['EXP'], 'components': ['MO', 'NI'], 'conditions': {'P': 101325.0, 'T': 298.15}, 'output': 'HM_FORM', 'solver': {'mode': 'manual', 'sublattice_site_ratios': [1.0, 1.0, 2.0], 'sublattice_configurations': [['NI', 'NI', 'MO']]}, 'values': [[[-1684.6201033200487]]]}
# N= [[-1684.6201033200487]]
# ['EXP']
# ['LIQUID', 'MO0.98NI0.02_229_CI2', 'MO7NI7_19_OP56', 'MONI4_87_TI10', 'MONI3RT', 'MONI3_59_OP8', 'BCC_A2', 'D_NIMO', 'FCC_A1', 'DELTA', 'MONI4', 'D0A_59', 'EXP']
# (1000.0, 3000.0)
