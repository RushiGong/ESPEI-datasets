# %%
from pycalphad import Database, variables as v
from espei.datasets import recursive_glob, load_datasets
from espei.plot import dataplot
from tinydb import where, Query
import matplotlib.pyplot as plt

# %%
comps = ['NB', 'NI','VA']
#phases = list(dbf.phases.keys())
#print(phases)
conds = {v.N: 1.0, v.P: 101325, v.T: (300, 4000, 20), v.X('NB'): (0, 1, 0.02)}
datasets = load_datasets(recursive_glob('.','*.json'))

datasets.update({'reference':'MPDS'},Query().reference.search('C10'))
for records in datasets:

    if records['reference']!='MPDS':
        records['phases']=['EXP']
        print('S=',records)
        #for i in range(len(records['conditions']['T'])):
         #   records['conditions']['T'][i]=records['conditions']['T'][i]+273
        
        for i in range(len(records['values'])):
            print('N=',records['values'][i])
            for j in range(len(records['values'][i])):
                records['values'][i][j][0] = 'EXP'
        #print('Y=',records)
   
    a=records['phases']
    records['phases']=['D_NIMO' if o=='MO7NI7_19_OP56' else o for o in records['phases']]
    records['phases']=['MONI3' if o=='MONI3_59_OP' else o for o in records['phases']]
    records['phases']=['MU_PHASE' if o=='NB7NI6_166_HR39' else o for o in records['phases']]
    records['phases']=['LIQUID' if o=='L' else o for o in records['phases']]
    records['phases']=['DELTA' if o=='NBNI3_59_OP8' else o for o in records['phases']]
    records['phases']=['FCC_A1' if o=='NB0.06NI0.94_225_CF4' or o=='FCC' else o for o in records['phases']]
    records['phases']=['MONI3' if o=='MONI3_59_OP8' else o for o in records['phases']]
    records['phases']=['BCC_A2' if o=='NB_229_CI2'or o=='NB0.002FE0.998_229_CI2' else o for o in records['phases']]
    datasets.update({'phases':records['phases']},where('phases')==a)
    print(records['phases'])
    for i in range(len(records['values'])):
        for j in range(len(records['values'][i])):
            records['values'][i][j] = ['D_NIMO' if o=='MO7NI7_19_OP56'  else o for o in records['values'][i][j]]
            records['values'][i][j] = ['MONI3' if o=='MONI3_59_OP' else o for o in records['values'][i][j]]
            records['values'][i][j] = ['MU_PHASE' if o=='NB7NI6_166_HR39'  else o for o in records['values'][i][j]]
            records['values'][i][j] = ['LIQUID' if o=='L' else o for o in records['values'][i][j]]
            records['values'][i][j] = ['DELTA' if o=='NBNI3_59_OP8' else o for o in records['values'][i][j]]
            records['values'][i][j] = ['FCC_A1' if o=='MONI4_87_TI10'or o=='FCC' else o for o in records['values'][i][j]]
            records['values'][i][j] = ['MONI3' if o=='MONI3_59_OP8' else o for o in records['values'][i][j]]
            records['values'][i][j] = ['BCC_A2' if o=='NB_229_CI2' or o=='NB0.002FE0.998_229_CI2' else o for o in records['values'][i][j]]
phases_1 = [r['phases'] for r in datasets]
phases_db = []
for i in phases_1:
    for j in i:
        if j not in phases_db:
            phases_db.append(j)
phases_db.append('EXP')
print(phases_db)
dataplot(comps, phases_db, conds,datasets,tielines=False)
#plt.ylim(0,1500)
#plt.xlim(0.4,0.9)
# Out:
# ['LIQUID', 'BCC_A2', 'MU_PHASE', 'DELTA', 'NB0.06NI0.94_225_CF4']
# ['NB0.06NI0.94_225_CF4', 'LIQUID', 'DELTA', 'NBNI8RT']
# ['MU_PHASE', 'DELTA', 'LIQUID', 'BCC_A2']
# ['DELTA', 'NBNI8RT', 'NB0.06NI0.94_225_CF4', 'LIQUID', 'MU_PHASE']
# ['NBNI8RT', 'DELTA']
# ['BCC_A2', 'MU_PHASE', 'LIQUID']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1871.0504587155956, 1772.9999999999995, 1671.509174311926]}, 'values': [[['BCC_A2', ['NB'], [0.9755143772994993]], ['LIQUID', ['NB'], [None]]], [['BCC_A2', ['NB'], [0.9783132530120481]], ['LIQUID', ['NB'], [None]]], [['BCC_A2', ['NB'], [0.9583942585545325]], ['LIQUID', ['NB'], [None]]]], 'reference': 'A.Wicker-1970'}
# N= [['BCC_A2', ['NB'], [0.9755143772994993]], ['LIQUID', ['NB'], [None]]]
# N= [['BCC_A2', ['NB'], [0.9783132530120481]], ['LIQUID', ['NB'], [None]]]
# N= [['BCC_A2', ['NB'], [0.9583942585545325]], ['LIQUID', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [2275.2935779816507, 2170.3623853211, 2072.311926605504, 1871.0504587155958, 1771.2798165137613, 1673.229357798165]}, 'values': [[['LIQUID', ['NB'], [0.8149157573939269]], ['BCC_A2', ['NB'], [None]]], [['LIQUID', ['NB'], [0.7881136604083435]], ['BCC_A2', ['NB'], [None]]], [['LIQUID', ['NB'], [0.7392774242448167]], ['BCC_A2', ['NB'], [None]]], [['LIQUID', ['NB'], [0.6842923463184323]], ['BCC_A2', ['NB'], [None]]], [['LIQUID', ['NB'], [0.6375223041576528]], ['BCC_A2', ['NB'], [None]]], [['LIQUID', ['NB'], [0.5866206635190828]], ['BCC_A2', ['NB'], [None]]]], 'reference': 'A.Wicker-1970', 'weights': 10}
# N= [['LIQUID', ['NB'], [0.8149157573939269]], ['BCC_A2', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.7881136604083435]], ['BCC_A2', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.7392774242448167]], ['BCC_A2', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.6842923463184323]], ['BCC_A2', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.6375223041576528]], ['BCC_A2', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.5866206635190828]], ['BCC_A2', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1647.3560839838651, 1582.3222732889485]}, 'values': [[['BCC_A2', ['NB'], [0.04911788291900558]], ['LIQUID', ['NB'], [None]]], [['BCC_A2', ['NB'], [0.10505212510024058]], ['LIQUID', ['NB'], [None]]]], 'reference': 'Chen-2005'}
# N= [['BCC_A2', ['NB'], [0.04911788291900558]], ['LIQUID', ['NB'], [None]]]
# N= [['BCC_A2', ['NB'], [0.10505212510024058]], ['LIQUID', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1322.3119266055041]}, 'values': [[['BCC_A2', ['NB'], [0.9530467874117702]], ['MU_PHASE', ['NB'], [None]]]], 'reference': 'Chen-2005'}
# N= [['BCC_A2', ['NB'], [0.9530467874117702]], ['MU_PHASE', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1322.3119266055046]}, 'values': [[['DELTA', ['NB'], [0.23497449825514372]], ['FCC_A1', ['NB'], [None]]]], 'reference': 'Chen-2005'}
# N= [['DELTA', ['NB'], [0.23497449825514372]], ['FCC_A1', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1322.3119266055048]}, 'values': [[['DELTA', ['NB'], [0.2563170111639216]], ['MU_PHASE', ['NB'], [None]]]], 'reference': 'Chen-2005'}
# N= [['DELTA', ['NB'], [0.2563170111639216]], ['MU_PHASE', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1322.3119266055048]}, 'values': [[['FCC_A1', ['NB'], [0.09590393026891292]], ['DELTA', ['NB'], [None]]]], 'reference': 'Chen-2005'}
# N= [['FCC_A1', ['NB'], [0.09590393026891292]], ['DELTA', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1682.0806248853676, 1598.3489844742573]}, 'values': [[['LIQUID', ['NB'], [0.04911788291900561]], ['BCC_A2', ['NB'], [None]]], [['LIQUID', ['NB'], [0.10505212510024052]], ['BCC_A2', ['NB'], [None]]]], 'reference': 'Chen-2005'}
# N= [['LIQUID', ['NB'], [0.04911788291900561]], ['BCC_A2', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.10505212510024052]], ['BCC_A2', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1592.380733944954, 1673.2293577981654, 1671.5091743119267, 1656.0275229357799]}, 'values': [[['LIQUID', ['NB'], [0.34500544774116115]], ['DELTA', ['NB'], [None]]], [['LIQUID', ['NB'], [0.3009063778047971]], ['DELTA', ['NB'], [None]]], [['LIQUID', ['NB'], [0.2499605236147735]], ['DELTA', ['NB'], [None]]], [['LIQUID', ['NB'], [0.2003979219630816]], ['DELTA', ['NB'], [None]]]], 'reference': 'Chen-2005', 'weights': 10}
# N= [['LIQUID', ['NB'], [0.34500544774116115]], ['DELTA', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.3009063778047971]], ['DELTA', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.2499605236147735]], ['DELTA', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.2003979219630816]], ['DELTA', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1554.5366972477063]}, 'values': [[['LIQUID', ['NB'], [0.44966997741950754]], ['MU_PHASE', ['NB'], [None]]]], 'reference': 'Chen-2005', 'weights': 10}
# N= [['LIQUID', ['NB'], [0.44966997741950754]], ['MU_PHASE', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1322.3119266055041]}, 'values': [[['MU_PHASE', ['NB'], [0.5633738097869853]], ['BCC_A2', ['NB'], [None]]]], 'reference': 'Chen-2005'}
# N= [['MU_PHASE', ['NB'], [0.5633738097869853]], ['BCC_A2', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1272.426605504587]}, 'values': [[['MU_PHASE', ['NB'], [0.49523835841399666]], ['DELTA', ['NB'], [None]]]], 'reference': 'Chen-2005', 'weights': 10}
# N= [['MU_PHASE', ['NB'], [0.49523835841399666]], ['DELTA', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1451.3256880733945]}, 'values': [[['MU_PHASE', ['NB'], [0.5240719101833282]], ['LIQUID', ['NB'], [None]]]], 'reference': 'Chen-2005'}
# N= [['MU_PHASE', ['NB'], [0.5240719101833282]], ['LIQUID', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1423.8579200669594, 1492.0945033645003]}, 'values': [[['FCC_A1', ['NB'], [0.1146070344306046]], ['DELTA', ['NB'], [None]]], [['FCC_A1', ['NB'], [0.14520177824766986]], ['DELTA', ['NB'], [None]]]], 'reference': 'Grube-1939'}
# N= [['FCC_A1', ['NB'], [0.1146070344306046]], ['DELTA', ['NB'], [None]]]
# N= [['FCC_A1', ['NB'], [0.14520177824766986]], ['DELTA', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1576.9514983315162, 1616.8111915067016, 1653.6896399819386]}, 'values': [[['FCC_A1', ['NB'], [0.14814814814814817]], ['LIQUID', ['NB'], [None]]], [['FCC_A1', ['NB'], [0.09946659911968667]], ['LIQUID', ['NB'], [None]]], [['FCC_A1', ['NB'], [0.04946935239332903]], ['LIQUID', ['NB'], [None]]]], 'reference': 'Grube-1939'}
# N= [['FCC_A1', ['NB'], [0.14814814814814817]], ['LIQUID', ['NB'], [None]]]
# N= [['FCC_A1', ['NB'], [0.09946659911968667]], ['LIQUID', ['NB'], [None]]]
# N= [['FCC_A1', ['NB'], [0.04946935239332903]], ['LIQUID', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1641.6721511877622]}, 'values': [[['LIQUID', ['NB'], [0.30002092487968196]], ['DELTA', ['NB'], [None]]]], 'reference': 'Grube-1939'}
# N= [['LIQUID', ['NB'], [0.30002092487968196]], ['DELTA', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1576.203709210251, 1623.0275327364236, 1653.9368839550225, 1693.4683869120383]}, 'values': [[['LIQUID', ['NB'], [0.199314251311476]], ['FCC_A1', ['NB'], [None]]], [['LIQUID', ['NB'], [0.14894072385399576]], ['FCC_A1', ['NB'], [None]]], [['LIQUID', ['NB'], [0.10029882196598428]], ['FCC_A1', ['NB'], [None]]], [['LIQUID', ['NB'], [0.04962537123306279]], ['FCC_A1', ['NB'], [None]]]], 'reference': 'Grube-1939'}
# N= [['LIQUID', ['NB'], [0.199314251311476]], ['FCC_A1', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.14894072385399576]], ['FCC_A1', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.10029882196598428]], ['FCC_A1', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.04962537123306279]], ['FCC_A1', ['NB'], [None]]]
# ['EXP']
# S= {'comment': 'text1 to write the comments', 'reference': 'text2 to write the reference', 'weight': 50, 'phases': ['EXP'], 'values': [[['DELTA', ['NB'], [0.23723533]], ['NBNI8', ['NB'], [0.11111111]], ['FCC_A1', ['NB'], [0.066636613]]], [['DELTA', ['NB'], [0.24196208]], ['LIQUID', ['NB'], [0.19125585]], ['FCC_A1', ['NB'], [0.17362798]]], [['LIQUID', ['NB'], [0.40449156]], ['MU_PHASE', ['NB'], [0.4797399]], ['DELTA', ['NB'], [0.27158006]]], [['BCC_A2', ['NB'], [0.95749686]], ['MU_PHASE', ['NB'], [0.58490976]], ['LIQUID', ['NB'], [0.5071741]]]], 'components': ['NB', 'NI'], 'output': 'ZPF', 'broadcast_conditions': False, 'conditions': {'P': 101325.0, 'T': [647.55233959, 1635.1343224, 1451.1592061, 1559.7907456]}}
# N= [['DELTA', ['NB'], [0.23723533]], ['NBNI8', ['NB'], [0.11111111]], ['FCC_A1', ['NB'], [0.066636613]]]
# N= [['DELTA', ['NB'], [0.24196208]], ['LIQUID', ['NB'], [0.19125585]], ['FCC_A1', ['NB'], [0.17362798]]]
# N= [['LIQUID', ['NB'], [0.40449156]], ['MU_PHASE', ['NB'], [0.4797399]], ['DELTA', ['NB'], [0.27158006]]]
# N= [['BCC_A2', ['NB'], [0.95749686]], ['MU_PHASE', ['NB'], [0.58490976]], ['LIQUID', ['NB'], [0.5071741]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1475.453656447598, 1423.687175302638, 1373.991257405181]}, 'values': [[['BCC_A2', ['NB'], [0.9619089261165614]], ['MU_PHASE', ['NB'], [None]]], [['BCC_A2', ['NB'], [0.962559314572166]], ['MU_PHASE', ['NB'], [None]]], [['BCC_A2', ['NB'], [0.9823679629686568]], ['MU_PHASE', ['NB'], [None]]]], 'reference': 'Duerden-and-H.rothery-1966'}
# N= [['BCC_A2', ['NB'], [0.9619089261165614]], ['MU_PHASE', ['NB'], [None]]]
# N= [['BCC_A2', ['NB'], [0.962559314572166]], ['MU_PHASE', ['NB'], [None]]]
# N= [['BCC_A2', ['NB'], [0.9823679629686568]], ['MU_PHASE', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1421.2038193822057, 1273.7066374571848]}, 'values': [[['DELTA', ['NB'], [0.23578561480533722]], ['FCC_A1', ['NB'], [None]]], [['DELTA', ['NB'], [0.23574721548692507]], ['FCC_A1', ['NB'], [None]]]], 'reference': 'Duerden-and-H.rothery-1966'}
# N= [['DELTA', ['NB'], [0.23578561480533722]], ['FCC_A1', ['NB'], [None]]]
# N= [['DELTA', ['NB'], [0.23574721548692507]], ['FCC_A1', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1419.430250863047, 1272.9128515468847]}, 'values': [[['DELTA', ['NB'], [0.2652750913671283]], ['MU_PHASE', ['NB'], [None]]], [['DELTA', ['NB'], [0.26572508337976997]], ['MU_PHASE', ['NB'], [None]]]], 'reference': 'Duerden-and-H.rothery-1966'}
# N= [['DELTA', ['NB'], [0.2652750913671283]], ['MU_PHASE', ['NB'], [None]]]
# N= [['DELTA', ['NB'], [0.26572508337976997]], ['MU_PHASE', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1703.1028156750217, 1684.5949441897405, 1638.9111550769971, 1604.8917589212788, 1575.783275596858, 1550.584922867621]}, 'values': [[['FCC_A1', ['NB'], [0.010841207568565658]], ['LIQUID', ['NB'], [None]]], [['FCC_A1', ['NB'], [0.01925185827951556]], ['LIQUID', ['NB'], [None]]], [['FCC_A1', ['NB'], [0.056247201612171366]], ['LIQUID', ['NB'], [None]]], [['FCC_A1', ['NB'], [0.08387011130552433]], ['LIQUID', ['NB'], [None]]], [['FCC_A1', ['NB'], [0.1159005427653659]], ['LIQUID', ['NB'], [None]]], [['FCC_A1', ['NB'], [0.14841036571600852]], ['LIQUID', ['NB'], [None]]]], 'reference': 'Duerden-and-H.rothery-1966'}
# N= [['FCC_A1', ['NB'], [0.010841207568565658]], ['LIQUID', ['NB'], [None]]]
# N= [['FCC_A1', ['NB'], [0.01925185827951556]], ['LIQUID', ['NB'], [None]]]
# N= [['FCC_A1', ['NB'], [0.056247201612171366]], ['LIQUID', ['NB'], [None]]]
# N= [['FCC_A1', ['NB'], [0.08387011130552433]], ['LIQUID', ['NB'], [None]]]
# N= [['FCC_A1', ['NB'], [0.1159005427653659]], ['LIQUID', ['NB'], [None]]]
# N= [['FCC_A1', ['NB'], [0.14841036571600852]], ['LIQUID', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1706.4267566750689, 1844.4051075593406, 2057.697721615441, 2190.909157112461, 2330.014287996388, 2438.836156408224, 1827.8958005995391]}, 'values': [[['LIQUID', ['NB'], [0.5553027433763051]], ['BCC_A2', ['NB'], [None]]], [['LIQUID', ['NB'], [0.5961566182200266]], ['BCC_A2', ['NB'], [None]]], [['LIQUID', ['NB'], [0.6534868006092891]], ['BCC_A2', ['NB'], [None]]], [['LIQUID', ['NB'], [0.7135199350211534]], ['BCC_A2', ['NB'], [None]]], [['LIQUID', ['NB'], [0.7789403738083647]], ['BCC_A2', ['NB'], [None]]], [['LIQUID', ['NB'], [0.8439624196670508]], ['BCC_A2', ['NB'], [None]]], [['LIQUID', ['NB'], [0.6119321382045468]], ['BCC_A2', ['NB'], [None]]]], 'reference': 'Duerden-and-H.rothery-1966', 'weights': 10}
# N= [['LIQUID', ['NB'], [0.5553027433763051]], ['BCC_A2', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.5961566182200266]], ['BCC_A2', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.6534868006092891]], ['BCC_A2', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.7135199350211534]], ['BCC_A2', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.7789403738083647]], ['BCC_A2', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.8439624196670508]], ['BCC_A2', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.6119321382045468]], ['BCC_A2', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1654.4538791936443, 1668.3508325227226, 1675.2543099859977, 1651.0807390668815, 1603.3653860143982, 1570.4397704440744, 1504.2645450543253]}, 'values': [[['LIQUID', ['NB'], [0.20214541191893853]], ['DELTA', ['NB'], [None]]], [['LIQUID', ['NB'], [0.23846636722198172]], ['DELTA', ['NB'], [None]]], [['LIQUID', ['NB'], [0.2492559757064312]], ['DELTA', ['NB'], [None]]], [['LIQUID', ['NB'], [0.2896250591552]], ['DELTA', ['NB'], [None]]], [['LIQUID', ['NB'], [0.3138502291584324]], ['DELTA', ['NB'], [None]]], [['LIQUID', ['NB'], [0.36063439873942243]], ['DELTA', ['NB'], [None]]], [['LIQUID', ['NB'], [0.4011324798984817]], ['DELTA', ['NB'], [None]]]], 'reference': 'Duerden-and-H.rothery-1966', 'weights': 10}
# N= [['LIQUID', ['NB'], [0.20214541191893853]], ['DELTA', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.23846636722198172]], ['DELTA', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.2492559757064312]], ['DELTA', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.2896250591552]], ['DELTA', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.3138502291584324]], ['DELTA', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.36063439873942243]], ['DELTA', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.4011324798984817]], ['DELTA', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1718.7253383752438, 1708.0347281335755, 1678.965244116917, 1650.7975440935923, 1619.7354954449559, 1588.67644674307, 1563.3700959307969]}, 'values': [[['LIQUID', ['NB'], [0.009810425864940908]], ['FCC_A1', ['NB'], [None]]], [['LIQUID', ['NB'], [0.018688468279688064]], ['FCC_A1', ['NB'], [None]]], [['LIQUID', ['NB'], [0.05710698635099229]], ['FCC_A1', ['NB'], [None]]], [['LIQUID', ['NB'], [0.08323772253042505]], ['FCC_A1', ['NB'], [None]]], [['LIQUID', ['NB'], [0.11527415388376855]], ['FCC_A1', ['NB'], [None]]], [['LIQUID', ['NB'], [0.1478019765149169]], ['FCC_A1', ['NB'], [None]]], [['LIQUID', ['NB'], [0.16262171346458604]], ['FCC_A1', ['NB'], [None]]]], 'reference': 'Duerden-and-H.rothery-1966'}
# N= [['LIQUID', ['NB'], [0.009810425864940908]], ['FCC_A1', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.018688468279688064]], ['FCC_A1', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.05710698635099229]], ['FCC_A1', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.08323772253042505]], ['FCC_A1', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.11527415388376855]], ['FCC_A1', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.1478019765149169]], ['FCC_A1', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.16262171346458604]], ['FCC_A1', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1483.9051064343603, 1525.0949753141876, 1541.8352781738122, 1557.6917967206077]}, 'values': [[['LIQUID', ['NB'], [0.42625643394829743]], ['MU_PHASE', ['NB'], [None]]], [['LIQUID', ['NB'], [0.4531569564640228]], ['MU_PHASE', ['NB'], [None]]], [['LIQUID', ['NB'], [0.4752185648704735]], ['MU_PHASE', ['NB'], [None]]], [['LIQUID', ['NB'], [0.5125163028356245]], ['MU_PHASE', ['NB'], [None]]]], 'reference': 'Duerden-and-H.rothery-1966', 'weights': 10}
# N= [['LIQUID', ['NB'], [0.42625643394829743]], ['MU_PHASE', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.4531569564640228]], ['MU_PHASE', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.4752185648704735]], ['MU_PHASE', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.5125163028356245]], ['MU_PHASE', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1273.6100391718041]}, 'values': [[['MU_PHASE', ['NB'], [0.5399244163416099]], ['BCC_A2', ['NB'], [None]]]], 'reference': 'Duerden-and-H.rothery-1966'}
# N= [['MU_PHASE', ['NB'], [0.5399244163416099]], ['BCC_A2', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1071.1716391467648, 1111.3317978881723, 1170.677934471925, 1240.0706068551722]}, 'values': [[['DELTA', ['NI'], [0.7589603264592635]], ['FCC_A1', ['NI'], [None]]], [['DELTA', ['NI'], [0.7588922944275152]], ['FCC_A1', ['NI'], [None]]], [['DELTA', ['NI'], [0.7590004252001985]], ['FCC_A1', ['NI'], [None]]], [['DELTA', ['NI'], [0.7589265466657218]], ['FCC_A1', ['NI'], [None]]]], 'reference': 'Murametsu-1972'}
# N= [['DELTA', ['NI'], [0.7589603264592635]], ['FCC_A1', ['NI'], [None]]]
# N= [['DELTA', ['NI'], [0.7588922944275152]], ['FCC_A1', ['NI'], [None]]]
# N= [['DELTA', ['NI'], [0.7590004252001985]], ['FCC_A1', ['NI'], [None]]]
# N= [['DELTA', ['NI'], [0.7589265466657218]], ['FCC_A1', ['NI'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1171.3322703328372]}, 'values': [[['DELTA', ['NI'], [0.7348802943330263]], ['MU_PHASE', ['NI'], [None]]]], 'reference': 'Murametsu-1972'}
# N= [['DELTA', ['NI'], [0.7348802943330263]], ['MU_PHASE', ['NI'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1172.3669441358634, 1242.5904919878867]}, 'values': [[['MU_PHASE', ['NI'], [0.4376183447067443]], ['BCC_A2', ['NI'], [None]]], [['MU_PHASE', ['NI'], [0.43786182773141213]], ['BCC_A2', ['NI'], [None]]]], 'reference': 'Murametsu-1972'}
# N= [['MU_PHASE', ['NI'], [0.4376183447067443]], ['BCC_A2', ['NI'], [None]]]
# N= [['MU_PHASE', ['NI'], [0.43786182773141213]], ['BCC_A2', ['NI'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1242.7187553669528]}, 'values': [[['MU_PHASE', ['NI'], [0.5137527690759167]], ['DELTA', ['NI'], [None]]]], 'reference': 'Murametsu-1972', 'weights': 10}
# N= [['MU_PHASE', ['NI'], [0.5137527690759167]], ['DELTA', ['NI'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1376.9083220077323, 1073.4139023982034]}, 'values': [[['BCC_A2', ['NB'], [0.9623652994229674]], ['MU_PHASE', ['NB'], [None]]], [['BCC_A2', ['NB'], [0.9828343008417637]], ['MU_PHASE', ['NB'], [None]]]], 'reference': 'V.N. Svechnikov-1964'}
# N= [['BCC_A2', ['NB'], [0.9623652994229674]], ['MU_PHASE', ['NB'], [None]]]
# N= [['BCC_A2', ['NB'], [0.9828343008417637]], ['MU_PHASE', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1628.9714796246822, 1592.5070950232403]}, 'values': [[['FCC_A1', ['NB'], [0.06578548049832184]], ['LIQUID', ['NB'], [None]]], [['FCC_A1', ['NB'], [0.09562089873766719]], ['LIQUID', ['NB'], [None]]]], 'reference': 'V.N. Svechnikov-1964'}
# N= [['FCC_A1', ['NB'], [0.06578548049832184]], ['LIQUID', ['NB'], [None]]]
# N= [['FCC_A1', ['NB'], [0.09562089873766719]], ['LIQUID', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1373.7898174454303]}, 'values': [[['FCC_A1', ['NB'], [0.10700460362247938]], ['MU_PHASE', ['NB'], [None]]]], 'reference': 'V.N. Svechnikov-1964'}
# N= [['FCC_A1', ['NB'], [0.10700460362247938]], ['MU_PHASE', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1719.3755414239213, 1659.4424047173761]}, 'values': [[['LIQUID', ['NB'], [0.6348451650852494]], ['BCC_A2', ['NB'], [None]]], [['LIQUID', ['NB'], [0.6183129588257394]], ['BCC_A2', ['NB'], [None]]]], 'reference': 'V.N. Svechnikov-1964'}
# N= [['LIQUID', ['NB'], [0.6348451650852494]], ['BCC_A2', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.6183129588257394]], ['BCC_A2', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1509.7925897581379, 1518.4009262802326, 1531.2939859842647, 1538.440052557271, 1549.1081090841158, 1563.492606355902, 1577.765294422804, 1590.5562674615073, 1591.3092781500507, 1598.0907494897401]}, 'values': [[['LIQUID', ['NB'], [0.43675536632098416]], ['DELTA', ['NB'], [None]]], [['LIQUID', ['NB'], [0.44541120439347676]], ['DELTA', ['NB'], [None]]], [['LIQUID', ['NB'], [0.4605439205307396]], ['DELTA', ['NB'], [None]]], [['LIQUID', ['NB'], [0.4708014775482256]], ['DELTA', ['NB'], [None]]], [['LIQUID', ['NB'], [0.49182883052432963]], ['DELTA', ['NB'], [None]]], [['LIQUID', ['NB'], [0.5021363891738133]], ['DELTA', ['NB'], [None]]], [['LIQUID', ['NB'], [0.5248004622373093]], ['DELTA', ['NB'], [None]]], [['LIQUID', ['NB'], [0.5512152132743222]], ['DELTA', ['NB'], [None]]], [['LIQUID', ['NB'], [0.5479967748947363]], ['DELTA', ['NB'], [None]]], [['LIQUID', ['NB'], [0.5985473136970443]], ['DELTA', ['NB'], [None]]]], 'reference': 'V.N. Svechnikov-1964', 'weights': 10}
# N= [['LIQUID', ['NB'], [0.43675536632098416]], ['DELTA', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.44541120439347676]], ['DELTA', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.4605439205307396]], ['DELTA', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.4708014775482256]], ['DELTA', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.49182883052432963]], ['DELTA', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.5021363891738133]], ['DELTA', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.5248004622373093]], ['DELTA', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.5512152132743222]], ['DELTA', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.5479967748947363]], ['DELTA', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.5985473136970443]], ['DELTA', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1579.1667984996732, 1629.4182303172395, 1676.7451222366285, 1732.3454091904387]}, 'values': [[['LIQUID', ['NB'], [0.12991424025645287]], ['FCC_A1', ['NB'], [None]]], [['LIQUID', ['NB'], [0.0964131468179864]], ['FCC_A1', ['NB'], [None]]], [['LIQUID', ['NB'], [0.06611549126950672]], ['FCC_A1', ['NB'], [None]]], [['LIQUID', ['NB'], [0.0014894930598429446]], ['FCC_A1', ['NB'], [None]]]], 'reference': 'V.N. Svechnikov-1964'}
# N= [['LIQUID', ['NB'], [0.12991424025645287]], ['FCC_A1', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.0964131468179864]], ['FCC_A1', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.06611549126950672]], ['FCC_A1', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.0014894930598429446]], ['FCC_A1', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1515.9041781224803, 1609.7514773051619, 1653.4348475262732, 1699.4355850503453, 1696.7443861014906, 1704.1335161633747, 1692.6589749804334, 1687.0383748636239, 1605.0550045730656]}, 'values': [[['LIQUID', ['NB'], [0.4013375436559388]], ['MU_PHASE', ['NB'], [None]]], [['LIQUID', ['NB'], [0.34987030826700594]], ['MU_PHASE', ['NB'], [None]]], [['LIQUID', ['NB'], [0.3222338506881822]], ['MU_PHASE', ['NB'], [None]]], [['LIQUID', ['NB'], [0.2784952008850289]], ['MU_PHASE', ['NB'], [None]]], [['LIQUID', ['NB'], [0.25591113043272945]], ['MU_PHASE', ['NB'], [None]]], [['LIQUID', ['NB'], [0.2393066995936673]], ['MU_PHASE', ['NB'], [None]]], [['LIQUID', ['NB'], [0.2274074223255898]], ['MU_PHASE', ['NB'], [None]]], [['LIQUID', ['NB'], [0.20856402952040798]], ['MU_PHASE', ['NB'], [None]]], [['LIQUID', ['NB'], [0.14889763763122826]], ['MU_PHASE', ['NB'], [None]]]], 'reference': 'V.N. Svechnikov-1964', 'weights': 10}
# N= [['LIQUID', ['NB'], [0.4013375436559388]], ['MU_PHASE', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.34987030826700594]], ['MU_PHASE', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.3222338506881822]], ['MU_PHASE', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.2784952008850289]], ['MU_PHASE', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.25591113043272945]], ['MU_PHASE', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.2393066995936673]], ['MU_PHASE', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.2274074223255898]], ['MU_PHASE', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.20856402952040798]], ['MU_PHASE', ['NB'], [None]]]
# N= [['LIQUID', ['NB'], [0.14889763763122826]], ['MU_PHASE', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1075.5927235125037, 1276.1118376780353]}, 'values': [[['MU_PHASE', ['NB'], [0.5820434416956666]], ['BCC_A2', ['NB'], [None]]], [['MU_PHASE', ['NB'], [0.5818167676306103]], ['BCC_A2', ['NB'], [None]]]], 'reference': 'V.N. Svechnikov-1964'}
# N= [['MU_PHASE', ['NB'], [0.5820434416956666]], ['BCC_A2', ['NB'], [None]]]
# N= [['MU_PHASE', ['NB'], [0.5818167676306103]], ['BCC_A2', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1276.8750570331115, 1073.9996854063988]}, 'values': [[['MU_PHASE', ['NB'], [0.49747012576104915]], ['DELTA', ['NB'], [None]]], [['MU_PHASE', ['NB'], [0.5180969101074828]], ['DELTA', ['NB'], [None]]]], 'reference': 'V.N. Svechnikov-1964', 'weights': 10}
# N= [['MU_PHASE', ['NB'], [0.49747012576104915]], ['DELTA', ['NB'], [None]]]
# N= [['MU_PHASE', ['NB'], [0.5180969101074828]], ['DELTA', ['NB'], [None]]]
# ['EXP']
# S= {'components': ['NB', 'NI'], 'phases': ['EXP'], 'broadcast_conditions': 'false', 'output': 'ZPF', 'conditions': {'P': 101325.0, 'T': [1462.2712470476467, 1498.3272849877737, 1504.6765894442387, 1545.0124892965255, 1553.6499934372857, 1572.0275377043554]}, 'values': [[['MU_PHASE', ['NB'], [0.48854261215470235]], ['LIQUID', ['NB'], [None]]], [['MU_PHASE', ['NB'], [0.5038353335143577]], ['LIQUID', ['NB'], [None]]], [['MU_PHASE', ['NB'], [0.5221464867256085]], ['LIQUID', ['NB'], [None]]], [['MU_PHASE', ['NB'], [0.5444533259071651]], ['LIQUID', ['NB'], [None]]], [['MU_PHASE', ['NB'], [0.5498857254368719]], ['LIQUID', ['NB'], [None]]], [['MU_PHASE', ['NB'], [0.5989045475789836]], ['LIQUID', ['NB'], [None]]]], 'reference': 'V.N. Svechnikov-1964'}
# N= [['MU_PHASE', ['NB'], [0.48854261215470235]], ['LIQUID', ['NB'], [None]]]
# N= [['MU_PHASE', ['NB'], [0.5038353335143577]], ['LIQUID', ['NB'], [None]]]
# N= [['MU_PHASE', ['NB'], [0.5221464867256085]], ['LIQUID', ['NB'], [None]]]
# N= [['MU_PHASE', ['NB'], [0.5444533259071651]], ['LIQUID', ['NB'], [None]]]
# N= [['MU_PHASE', ['NB'], [0.5498857254368719]], ['LIQUID', ['NB'], [None]]]
# N= [['MU_PHASE', ['NB'], [0.5989045475789836]], ['LIQUID', ['NB'], [None]]]
# ['EXP']
# ['LIQUID', 'BCC_A2', 'MU_PHASE', 'DELTA', 'NB0.06NI0.94_225_CF4', 'NBNI8RT', 'FCC_A1', 'NBNI8', 'EXP']
# <AxesSubplot:title={'center':'Nb-Ni'}, xlabel='X(NB)', ylabel='Temperature (K)'>
